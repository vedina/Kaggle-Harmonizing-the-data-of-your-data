# %% [markdown]
# # SDRF Extraction Pipeline Kaggle: Harmonizing the Data of Your Data
#
# rules + LLM + normalisation (tbd iterative)
# plain langchain, no dspy

# %%
import time
from datetime import timedelta
start_time = time.monotonic()

# %% [markdown]
# # Dependencies, configuration, LocalAI

# %%
# ── Kaggle secrets ───────────────────────────────────────────────────────────
import os
try:
    from kaggle_secrets import UserSecretsClient
    user_secrets = UserSecretsClient()
    def get_secret_safe(name, default=None):
        try: return user_secrets.get_secret(name)
        except Exception: return default
    api_key  = get_secret_safe('LLM_API_KEY', 'sk-dummy')
    api_base = get_secret_safe('LLM_API_BASE', None)
    LLM_MODEL = get_secret_safe("LLM_MODEL", None)
    # Force into environment (CRITICAL)
    os.environ["OPENAI_API_KEY"] = api_key
    # (Optional but helps LiteLLM routing)
    os.environ["OPENAI_API_BASE"] = "https://api.openai.com/v1"
except Exception as x:
    print(x)
    api_key = None
    api_base = None
    LLM_MODEL = None
if LLM_MODEL is None:
    api_key = 'sk-dummy'
    api_base = "http://127.0.0.1:8080/v1"
    CONTEXT_SIZE = 24576
    # Tested models:
    # phi-2-chat @ kaggle (GPU P100)
    # LLM_PREFIX = "huggingface://numind/"
    LLM_PREFIX = ""
    LLM_MODEL = "qwen3-vl-4b-instruct"

print(f'api_base={api_base}, api_key={api_key[:4]}, model={LLM_MODEL}, prefix={LLM_PREFIX}')
# Out:
# A JWT Token is required to call Kaggle, but none found in environment variable KAGGLE_USER_SECRETS_TOKEN
# api_base=http://127.0.0.1:8080/v1, api_key=sk-d, model=qwen3-vl-4b-instruct, prefix=

# %%
LAUNCH_LOCAL_AI = api_base is None or api_base == "http://127.0.0.1:8080/v1"
LAUNCH_LOCAL_AI
# Out:
# True

# %% [markdown]
# ## LocalAI Server

# %%
# Create tmp folder to be used as a larger scratch space
from pathlib import Path

TMP_DIR = Path('../tmp')
TMP_DIR.mkdir(exist_ok=True)

# %%
# %%bash
# # Download and make executable the local-ai binary (https://github.com/mudler/LocalAI/releases)
# cd ../tmp
# if [ ! -f ./local-ai-* ]; then
#     echo Dowloading LocalAI ...
#     wget -q https://github.com/mudler/LocalAI/releases/download/v4.0.0/local-ai-v4.0.0-linux-amd64
# fi
# chmod +x local-ai-*
# pwd
# ls -al
# Out:
# /tmp/working/tmp
# total 44363
# drwxr-xr-x 2 root root         3 Mar 22 09:49 .
# drwxr-xr-x 7 root root         7 Mar 30 17:44 ..
# -rwxr-xr-x 1 root root 116822178 Mar 14 18:27 local-ai-v4.0.0-linux-amd64

# %%
# %%bash
# # Download Model Gallery
# mkdir /kaggle/tmp/models
# cd /kaggle/tmp/models
# git clone --filter=blob:none --sparse https://github.com/mudler/LocalAI.git
# cd LocalAI
# git sparse-checkout set gallery
# Out:
# mkdir: cannot create directory ‘/kaggle/tmp/models’: File exists
# fatal: destination path 'LocalAI' already exists and is not an empty directory.

# %%
import subprocess
import requests
import time
import signal
import os

# Use modified local model gallery
os.environ["GALLERIES"] = '[{"name":"localai", "url":"file:///kaggle/tmp/models/LocalAI/gallery/index.updated.yaml"}]'

class LocalAIServer:
    def __init__(self, binary_path: str, model_name: str, host: str = "127.0.0.1", port: int = 8080):
        self.binary_path = binary_path
        self.model_name = model_name
        self.host = host
        self.port = port
        self.proc = None

    def start(self):
        """Start LocalAI as a subprocess."""
        if self.proc is not None:
            raise RuntimeError("Server already running")
        
        self.proc = subprocess.Popen(
            [self.binary_path, "run", self.model_name, "--disable-web-ui"],
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True
        )
        self._wait_until_ready()

    def _wait_until_ready(self, timeout: int = 1200):
        """Poll the server until it responds or timeout."""
        url = f"http://{self.host}:{self.port}/v1/models"
        start_time = time.time()
        while True:
            try:
                res = requests.get(url, timeout=1)
                if res.status_code == 200:
                    print("LocalAI server is ready!")
                    break
            except requests.RequestException:
                pass  # server not ready yet
            if time.time() - start_time > timeout:
                raise TimeoutError("LocalAI server did not start in time")
            time.sleep(1)

    def stop(self):
        """Stop the LocalAI server."""
        if self.proc:
            self.proc.terminate()  # SIGTERM
            try:
                self.proc.wait(timeout=5)
            except subprocess.TimeoutExpired:
                self.proc.kill()   # SIGKILL if needed
                self.proc.wait()
            self.proc = None
            print("LocalAI server stopped.")

# %%
# Set the context_size for the selected model from the local model gallery

import yaml

def set_context_size(yaml_path, model_name, context_size, output_path=None):
    with open(yaml_path, "r", encoding="utf-8") as f:
        data = yaml.safe_load(f)

    if not isinstance(data, list):
        raise ValueError("Expected a list of models")

    found = False

    for model in data:
        if model.get("name") == model_name:
            # Ensure overrides block exists
            overrides = model.get("overrides")
            if overrides is None:
                overrides = {}
                model["overrides"] = overrides

            # Set / update context_size
            overrides["context_size"] = context_size

            found = True
            break

    if not found:
        raise ValueError(f"Model '{model_name}' not found")

    out = output_path or yaml_path
    with open(out, "w", encoding="utf-8") as f:
        yaml.safe_dump(data, f, sort_keys=False)

    return out

if True:
    set_context_size(
        yaml_path = "/kaggle/tmp/models/LocalAI/gallery/index.yaml",
        model_name = LLM_MODEL,
        context_size = CONTEXT_SIZE,
        output_path = "/kaggle/tmp/models/LocalAI/gallery/index.updated.yaml"
    )

# %%
if LAUNCH_LOCAL_AI:
    server = LocalAIServer("/kaggle/tmp/local-ai-v4.0.0-linux-amd64", LLM_PREFIX + LLM_MODEL)
    os.chdir( "/kaggle/tmp")
    server.start()

    """"
    # Now the server is ready, you can query it:
    res = requests.post(
        "http://127.0.0.1:8080/v1/chat/completions",
        json={
            "model": LLM_MODEL,
            "messages": [{"role": "user", "content": "Explain LLMs in one sentence."}]
        },
        timeout=1200
    )
    print(res.json())
    """
else:
    """
    res = requests.post(
        f"{api_base}/chat/completions",
        headers={
            "Authorization": f"Bearer {api_key}",
            "Content-Type": "application/json"
        },        
        json={
            "model": LLM_MODEL,
            "messages": [{"role": "user", "content": "Explain LLMs in one sentence."}]
        },
        timeout=1200
    )    
    print(res.status_code)
    print(res.text)
    """
    server = None
# Out:
# LocalAI server is ready!

# %%
import logging

logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(levelname)s %(message)s')
log = logging.getLogger('sdrf')

# %%
print("CWD:", os.getcwd())
os.chdir("/kaggle/working")
# !pwd
# Out:
# CWD: /kaggle/tmp
# /kaggle/working

# %% [markdown]
# ##  Install & Import modelmess

# %%
# %pip install -q langchain langchain-openai langchain-core pydantic openai sdrf-pipelines[all] sdrf-pipelines[ontology] PyYAML 
# check if ols dep is in
from sdrf_pipelines.ols.ols import OlsClient, OLS_AVAILABLE
print(OLS_AVAILABLE)
# Out:
# 2026-03-30 20:54:33,323 INFO Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# 2026-03-30 20:54:33,323 INFO NumExpr defaulting to 16 threads.
# Note: you may need to restart the kernel to use updated packages.
# True

# %%
import sys

os.chdir("/kaggle/working")
# !cd /kaggle/working

repo_url = 'https://github.com/vedina/modelmess.git'
repo_dir = '/kaggle/working/modelmess'

#branch = "iterative"
branch = "main"

if os.path.exists(repo_dir):
    print("Repo already exists. Pulling latest changes...")
    # !cd {repo_dir} && git pull
else:
    print(f"Cloning repo (branch: {branch})...")
    # !git clone --branch {branch} --single-branch {repo_url}

# Add the src folder inside the repo to Python path
SOURCE_DIR = f"{repo_dir}/sdrf_pipeline"
# Remove any old modelmess paths (important)
sys.path = [p for p in sys.path if "modelmess" not in p]
# Add correct one at highest priority
sys.path.insert(0,SOURCE_DIR)

# Verify import
from src.rules_0000 import PaperJSON

print('modelmess sdrf_pipeline imported OK')
# %cd {SOURCE_DIR}
# !pwd
# Out:
# Repo already exists. Pulling latest changes...
# Already up to date.
# modelmess sdrf_pipeline imported OK
# /kaggle/working/modelmess/sdrf_pipeline
# /kaggle/working/modelmess/sdrf_pipeline

# %% [markdown]
# ## Configuration

# %%
ON_KAGGLE = Path('/kaggle').exists()

# ── LLM config ───────────────────────────────────────────────────────────────
LLM_API_BASE = api_base           # from Cell 0
LLM_API_KEY  = api_key
LLM_MODEL    = LLM_MODEL
RUN = 1

LLM_BACKEND = 'openai_compat'

TEMPERATURE = 0

BASE_DIR       = Path('/kaggle/input/competitions/harmonizing-the-data-of-your-data')
TRAIN_TEXT_DIR = BASE_DIR / 'Training_PubText' / 'PubText'
TRAIN_SDRF_DIR = BASE_DIR / 'Training_SDRFs' / 'HarmonizedFiles'
TEST_TEXT_DIR  = BASE_DIR / 'Test PubText' / 'Test PubText'
SAMPLE_SUB     = BASE_DIR / 'SampleSubmission.csv'
OUTPUT_DIR     = Path(f'/kaggle/working/output_sdrfs/{LLM_MODEL}/T{TEMPERATURE}/R{RUN}')
OUTPUT_DIR_RULES = Path(f'/kaggle/working/output_sdrfs/rules_0000')

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR_RULES.mkdir(parents=True, exist_ok=True)

SUBMISSION = "/kaggle/working/submission.csv"

print(f'Backend : {LLM_BACKEND}')
print(f'URL     : {LLM_API_BASE}')
print(f'Model   : {LLM_MODEL}')
print(f'Kaggle  : {ON_KAGGLE}')
print(f'Output  : {OUTPUT_DIR}')
# Out:
# Backend : openai_compat
# URL     : http://127.0.0.1:8080/v1
# Model   : qwen3-vl-4b-instruct
# Kaggle  : True
# Output  : /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1

# %% [markdown]
# # Run extraction pipeline

# %%
# !python main_fill.py --help
# Out:
# usage: main_fill.py [-h] [--pattern GLOB] [--stage {rules,llm,both}]
#                     [--rules-only] [--rules-dir RULES_DIR] [--llm-dir LLM_DIR]
#                     [--fill-from DIR] [--api-key API_KEY]
#                     [--base-url BASE_URL] [--model MODEL]
#                     [--max-tokens MAX_TOKENS] [--context-limit TOKENS]
#                     [--no-dedup] [--prompts TOML] [--dump-prompts TOML]
#                     [--verbose]
#                     [input]
#
# SDRF extraction -- rules + LLM gap-fill pipeline.
#
# positional arguments:
#   input                 Paper JSON source. Two forms: directory/ -> all *.json
#                         files in that folder path/to/file.json -> single file
#                         Use --pattern to filter files inside a directory. Not
#                         required when using --dump-prompts.
#
# options:
#   -h, --help            show this help message and exit
#   --pattern GLOB        Glob pattern inside the input directory (default:
#                         *.json). Example: --pattern 'PXD06*.json'
#   --stage {rules,llm,both}
#                         Which stage(s) to run (default: both).
#   --rules-only          Alias for --stage rules (backwards compat).
#   --rules-dir RULES_DIR
#                         Folder for rule-based CSVs (default: output/rules).
#   --llm-dir LLM_DIR     Folder for LLM-filled CSVs (default: output/llm).
#   --fill-from DIR       For --stage llm: folder of pre-computed rule CSVs to
#                         use as input. Falls back to --rules-dir if a file is
#                         missing.
#   --api-key API_KEY     LLM API key (default: OPENAI_API_KEY env).
#   --base-url BASE_URL   OpenAI-compatible base URL.
#   --model MODEL         Model name (default: gpt-4o-mini).
#   --max-tokens MAX_TOKENS
#                         Max LLM response tokens (default: 8192).
#   --context-limit TOKENS
#                         Context window size in tokens for trimming paper text
#                         (default: None). Examples: 8192 for older models,
#                         128000 for gpt-4o.
#   --no-dedup            One LLM call per row (disables deduplication).
#   --prompts TOML        Path to a TOML file overriding prompt templates.
#                         Missing sections fall back to built-in defaults. Use
#                         --dump-prompts to generate a starting file.
#   --dump-prompts TOML   Write the current default prompts to TOML and exit.
#                         Example: --dump-prompts prompts.toml
#   --verbose, -v
#
# SDRF Extraction -- two-stage pipeline
# =====================================
#
# Three stages, selectable via --stage:
#
#   rules  -- rule-based extraction only; writes CSVs to --rules-dir
#   llm    -- LLM gap-fill only; reads from --fill-from (or --rules-dir),
#             writes to --llm-dir.  Requires paper JSONs for context.
#   both   -- runs rules then llm in sequence (default)
#
# Typical iterative workflow
# --------------------------
#   # 1. Bootstrap rule output once (fast, free)
#   python main_fill.py papers/ --stage rules --rules-dir output/rules
#
#   # 2. Dump default prompts to a file, then edit them
#   python main_fill.py papers/ --dump-prompts my_prompts.toml
#
#   # 3. Fill gaps with model A, custom prompts
#   python main_fill.py papers/ --stage llm \
#       --fill-from output/rules --llm-dir output/llm_gpt4o \
#       --model gpt-4o --api-key $OPENAI_API_KEY \
#       --prompts my_prompts.toml
#
#   # 4. Fill gaps with model B (same rules, different output folder)
#   python main_fill.py papers/ --stage llm \
#       --fill-from output/rules --llm-dir output/llm_llama \
#       --model llama3.1:70b --base-url http://localhost:11434/v1 --api-key ollama
#
#   # 5. Re-fill a subset (pass a folder of specific rule CSVs)
#   python main_fill.py papers/ --stage llm \
#       --fill-from output/rules_subset --llm-dir output/llm_retry

# %% [markdown]
# ## Bootstrap with rules
# adapted from https://www.kaggle.com/code/nikitagajbhiye30/harmonizing-0000

# %%
log.info(f"Writing into {OUTPUT_DIR}")
log.info(f"Reading from {TEST_TEXT_DIR}")
pxd_files_only = f"{TEST_TEXT_DIR}/PXD*.json"

#{TEST_TEXT_DIR}/PXD*.json
# !python main_fill.py "{TEST_TEXT_DIR}" --pattern PXD*.json  --stage rules --rules-dir {OUTPUT_DIR_RULES}
# Out:
# 2026-03-30 20:54:39,372 INFO Writing into /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1
# 2026-03-30 20:54:39,373 INFO Reading from /kaggle/input/competitions/harmonizing-the-data-of-your-data/Test PubText/Test PubText
# 20:54:39 [INFO] Pattern 'PXD*.json' in /kaggle/input/competitions/harmonizing-the-data-of-your-data/Test PubText/Test PubText -> 15 file(s)
# 20:54:39 [INFO] -- [1/15] PXD004010_PubText.json --
# 20:54:39 [INFO] [rules] PXD004010_PubText.json -> 10 rows, 53/82 fields filled in row 0
# 20:54:41 [INFO] Written 10 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD004010_PubText.sdrf.csv
# 20:54:41 [INFO] -- [2/15] PXD016436_PubText.json --
# 20:54:41 [INFO] [rules] PXD016436_PubText.json -> 18 rows, 61/82 fields filled in row 0
# 20:54:41 [INFO] Written 18 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD016436_PubText.sdrf.csv
# 20:54:41 [INFO] -- [3/15] PXD019519_PubText.json --
# 20:54:41 [INFO] [rules] PXD019519_PubText.json -> 6 rows, 63/82 fields filled in row 0
# 20:54:41 [INFO] Written 6 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD019519_PubText.sdrf.csv
# 20:54:41 [INFO] -- [4/15] PXD025663_PubText.json --
# 20:54:41 [INFO] [rules] PXD025663_PubText.json -> 12 rows, 59/82 fields filled in row 0
# 20:54:41 [INFO] Written 12 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD025663_PubText.sdrf.csv
# 20:54:41 [INFO] -- [5/15] PXD040582_PubText.json --
# 20:54:41 [INFO] [rules] PXD040582_PubText.json -> 24 rows, 63/82 fields filled in row 0
# 20:54:41 [INFO] Written 24 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD040582_PubText.sdrf.csv
# 20:54:41 [INFO] -- [6/15] PXD050621_PubText.json --
# 20:54:41 [INFO] [rules] PXD050621_PubText.json -> 9 rows, 48/82 fields filled in row 0
# 20:54:41 [INFO] Written 9 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD050621_PubText.sdrf.csv
# 20:54:41 [INFO] -- [7/15] PXD061009_PubText.json --
# 20:54:41 [INFO] [rules] PXD061009_PubText.json -> 2 rows, 60/82 fields filled in row 0
# 20:54:41 [INFO] Written 2 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD061009_PubText.sdrf.csv
# 20:54:41 [INFO] -- [8/15] PXD061090_PubText.json --
# 20:54:41 [INFO] [rules] PXD061090_PubText.json -> 6 rows, 53/82 fields filled in row 0
# 20:54:41 [INFO] Written 6 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD061090_PubText.sdrf.csv
# 20:54:41 [INFO] -- [9/15] PXD061136_PubText.json --
# 20:54:41 [INFO] [rules] PXD061136_PubText.json -> 2 rows, 54/82 fields filled in row 0
# 20:54:41 [INFO] Written 2 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD061136_PubText.sdrf.csv
# 20:54:41 [INFO] -- [10/15] PXD061195_PubText.json --
# 20:54:41 [INFO] [rules] PXD061195_PubText.json -> 1376 rows, 64/82 fields filled in row 0
# 20:54:41 [INFO] Written 1376 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD061195_PubText.sdrf.csv
# 20:54:41 [INFO] -- [11/15] PXD061285_PubText.json --
# 20:54:41 [INFO] [rules] PXD061285_PubText.json -> 60 rows, 58/82 fields filled in row 0
# 20:54:41 [INFO] Written 60 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD061285_PubText.sdrf.csv
# 20:54:41 [INFO] -- [12/15] PXD062014_PubText.json --
# 20:54:41 [INFO] [rules] PXD062014_PubText.json -> 24 rows, 56/82 fields filled in row 0
# 20:54:41 [INFO] Written 24 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD062014_PubText.sdrf.csv
# 20:54:41 [INFO] -- [13/15] PXD062469_PubText.json --
# 20:54:41 [INFO] [rules] PXD062469_PubText.json -> 32 rows, 59/82 fields filled in row 0
# 20:54:41 [INFO] Written 32 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD062469_PubText.sdrf.csv
# 20:54:41 [INFO] -- [14/15] PXD062877_PubText.json --
# 20:54:41 [INFO] [rules] PXD062877_PubText.json -> 48 rows, 62/82 fields filled in row 0
# 20:54:41 [INFO] Written 48 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD062877_PubText.sdrf.csv
# 20:54:41 [INFO] -- [15/15] PXD064564_PubText.json --
# 20:54:41 [INFO] [rules] PXD064564_PubText.json -> 30 rows, 56/82 fields filled in row 0
# 20:54:41 [INFO] Written 30 rows -> /kaggle/working/output_sdrfs/rules_0000/PXD064564_PubText.sdrf.csv
#
# 15/15 file(s) processed.
#   Rules CSVs -> /kaggle/working/output_sdrfs/rules_0000/

# %%
MAX_TOKENS = 8192
#CONTEXT_LIMIT = CONTEXT_SIZE
CONTEXT_LIMIT = 22912
log.info(f"Writing into {OUTPUT_DIR}")
log.info(f"Reading from {TEST_TEXT_DIR}")
log.info(f"{api_base} {LLM_MODEL}")
# Out:
# 2026-03-30 20:54:42,356 INFO Writing into /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1
# 2026-03-30 20:54:42,356 INFO Reading from /kaggle/input/competitions/harmonizing-the-data-of-your-data/Test PubText/Test PubText
# 2026-03-30 20:54:42,356 INFO http://127.0.0.1:8080/v1 qwen3-vl-4b-instruct

# %% [markdown]
# ## Running LLM stage (gap filling)
#
# > python main_fill.py papers/ --stage llm  --fill-from output/rules --llm-dir output/llm_gpt4o  --model gpt-4o --api-key $OPENAI_API_KEY

# %%
# Running second (LLM) stage (gap filling)
# !python main_fill.py --stage llm --fill-from {OUTPUT_DIR_RULES} --max-tokens {MAX_TOKENS} --context-limit {CONTEXT_LIMIT} --llm-dir {OUTPUT_DIR}  --model {LLM_MODEL} --base-url {api_base} --api-key {api_key} --pattern PXD*.json "{TEST_TEXT_DIR}"
# Out:
# 20:54:42 [INFO] Pattern 'PXD*.json' in /kaggle/input/competitions/harmonizing-the-data-of-your-data/Test PubText/Test PubText -> 15 file(s)
# 20:54:42 [INFO] -- [1/15] PXD004010_PubText.json --
# 20:54:42 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD004010_PubText.sdrf.csv
# 20:54:44 [INFO] Deduplicated: 10 row(s) → 1 unique N/A pattern(s)
# 20:54:44 [INFO] Filling 63 field(s) for group of 10 row(s)…
# 20:54:44 [INFO] Chars: Paper9630 = M8027+A1493+T110
# 20:54:44 [INFO] Tokens: Paper2406 = M2006+A373+T27
# 20:54:44 [INFO] Context limit 22912 Available 10333 = CT22912-MT8192-FT4387
# 20:57:21 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 20:57:21 [INFO] Pass2 inventory approx tokens 12524/12524 available
# [llm_fillgaps debug] pass2_inventory_tokens~12524 available~12524 raw_chars=84592 trimmed_chars=50096
# 20:57:21 [INFO] Pass2 inventory trimmed 84592->50096 chars to stay within context budget.
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=88715 inventory_compact_chars=50096 pass2_chars=2188
# 20:57:24 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 20:57:24 [INFO] =============== Response received len=383
# 20:57:24 [INFO] [llm]   PXD004010_PubText.json -> 29/82 fields filled in row 0 (+10 via LLM)
# 20:57:24 [INFO] Written 10 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD004010_PubText.sdrf.csv
# 20:57:24 [INFO] -- [2/15] PXD016436_PubText.json --
# 20:57:24 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD016436_PubText.sdrf.csv
# 20:57:24 [INFO] Deduplicated: 18 row(s) → 1 unique N/A pattern(s)
# 20:57:24 [INFO] Filling 55 field(s) for group of 18 row(s)…
# 20:57:24 [INFO] Chars: Paper6853 = M6201+A577+T75
# 20:57:24 [INFO] Tokens: Paper1712 = M1550+A144+T18
# 20:57:24 [INFO] Context limit 22912 Available 10742 = CT22912-MT8192-FT3978
# 21:00:00 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:00:00 [INFO] Pass2 inventory approx tokens 9946/12499 available
# [llm_fillgaps debug] pass2_inventory_tokens~9946 available~12499 raw_chars=39787 trimmed_chars=39787
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=93982 inventory_compact_chars=39787 pass2_chars=2291
# 21:00:08 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:00:08 [INFO] =============== Response received len=3108
# 21:00:08 [INFO] [llm]   PXD016436_PubText.json -> 29/82 fields filled in row 0 (+2 via LLM)
# 21:00:08 [INFO] Written 18 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD016436_PubText.sdrf.csv
# 21:00:08 [INFO] -- [3/15] PXD019519_PubText.json --
# 21:00:08 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD019519_PubText.sdrf.csv
# 21:00:08 [INFO] Deduplicated: 6 row(s) → 1 unique N/A pattern(s)
# 21:00:08 [INFO] Filling 53 field(s) for group of 6 row(s)…
# 21:00:08 [INFO] Chars: Paper43567 = M42096+A1394+T77
# 21:00:08 [INFO] Tokens: Paper10891 = M10524+A348+T19
# 21:00:08 [INFO] Context limit 22912 Available 10801 = CT22912-MT8192-FT3919
# 21:00:08 [INFO] Paper text trimmed to fit context (limit=22912 tok, margin=1145): abstract 1394->1382 chars, methods 42096->41747 chars.
# 21:00:39 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:00:39 [INFO] Pass2 inventory approx tokens 1809/12497 available
# [llm_fillgaps debug] pass2_inventory_tokens~1809 available~12497 raw_chars=7239 trimmed_chars=7239
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=11971 inventory_compact_chars=7239 pass2_chars=2298
# 21:00:44 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:00:44 [INFO] =============== Response received len=1928
# 21:00:44 [INFO] [llm]   PXD019519_PubText.json -> 57/82 fields filled in row 0 (+28 via LLM)
# 21:00:44 [INFO] Written 6 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD019519_PubText.sdrf.csv
# 21:00:44 [INFO] -- [4/15] PXD025663_PubText.json --
# 21:00:44 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD025663_PubText.sdrf.csv
# 21:00:44 [INFO] Deduplicated: 12 row(s) → 1 unique N/A pattern(s)
# 21:00:44 [INFO] Filling 57 field(s) for group of 12 row(s)…
# 21:00:44 [INFO] Chars: Paper18589 = M16465+A2069+T55
# 21:00:44 [INFO] Tokens: Paper4646 = M4116+A517+T13
# 21:00:44 [INFO] Context limit 22912 Available 10594 = CT22912-MT8192-FT4126
# 21:02:58 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:02:58 [INFO] Pass2 inventory approx tokens 12500/12500 available
# [llm_fillgaps debug] pass2_inventory_tokens~12500 available~12500 raw_chars=63781 trimmed_chars=50000
# 21:02:58 [INFO] Pass2 inventory trimmed 63781->50000 chars to stay within context budget.
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=71663 inventory_compact_chars=50000 pass2_chars=2285
# 21:03:00 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:03:00 [INFO] =============== Response received len=340
# 21:03:00 [INFO] [llm]   PXD025663_PubText.json -> 34/82 fields filled in row 0 (+9 via LLM)
# 21:03:00 [INFO] Written 12 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD025663_PubText.sdrf.csv
# 21:03:00 [INFO] -- [5/15] PXD040582_PubText.json --
# 21:03:00 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD040582_PubText.sdrf.csv
# 21:03:00 [INFO] Deduplicated: 24 row(s) → 1 unique N/A pattern(s)
# 21:03:00 [INFO] Filling 53 field(s) for group of 24 row(s)…
# 21:03:00 [INFO] Chars: Paper18376 = M17042+A1207+T127
# 21:03:00 [INFO] Tokens: Paper4592 = M4260+A301+T31
# 21:03:00 [INFO] Context limit 22912 Available 10800 = CT22912-MT8192-FT3920
# 21:05:18 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:05:18 [INFO] Pass2 inventory approx tokens 9602/12494 available
# [llm_fillgaps debug] pass2_inventory_tokens~9602 available~12494 raw_chars=38410 trimmed_chars=38410
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=75599 inventory_compact_chars=38410 pass2_chars=2309
# 21:05:20 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:05:20 [INFO] =============== Response received len=300
# 21:05:20 [INFO] [llm]   PXD040582_PubText.json -> 36/82 fields filled in row 0 (+7 via LLM)
# 21:05:20 [INFO] Written 24 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD040582_PubText.sdrf.csv
# 21:05:20 [INFO] -- [6/15] PXD050621_PubText.json --
# 21:05:20 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD050621_PubText.sdrf.csv
# 21:05:20 [INFO] Deduplicated: 9 row(s) → 1 unique N/A pattern(s)
# 21:05:20 [INFO] Filling 68 field(s) for group of 9 row(s)…
# 21:05:20 [INFO] Chars: Paper12512 = M10943+A1424+T145
# 21:05:20 [INFO] Tokens: Paper3127 = M2735+A356+T36
# 21:05:20 [INFO] Context limit 22912 Available 10059 = CT22912-MT8192-FT4661
# 21:05:31 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:05:31 [INFO] Pass2 inventory approx tokens 1009/12539 available
# [llm_fillgaps debug] pass2_inventory_tokens~1009 available~12539 raw_chars=4039 trimmed_chars=4039
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=6845 inventory_compact_chars=4039 pass2_chars=2130
# 21:05:32 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:05:32 [INFO] =============== Response received len=143
# 21:05:32 [INFO] [llm]   PXD050621_PubText.json -> 18/82 fields filled in row 0 (+4 via LLM)
# 21:05:32 [INFO] Written 9 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD050621_PubText.sdrf.csv
# 21:05:32 [INFO] -- [7/15] PXD061009_PubText.json --
# 21:05:32 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD061009_PubText.sdrf.csv
# 21:05:32 [INFO] Deduplicated: 2 row(s) → 1 unique N/A pattern(s)
# 21:05:32 [INFO] Filling 56 field(s) for group of 2 row(s)…
# 21:05:32 [INFO] Chars: Paper32997 = M31369+A1523+T105
# 21:05:32 [INFO] Tokens: Paper8248 = M7842+A380+T26
# 21:05:32 [INFO] Context limit 22912 Available 10637 = CT22912-MT8192-FT4083
# 21:07:21 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:07:21 [INFO] Pass2 inventory approx tokens 4169/12504 available
# [llm_fillgaps debug] pass2_inventory_tokens~4169 available~12504 raw_chars=16679 trimmed_chars=16679
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=50805 inventory_compact_chars=16679 pass2_chars=2268
# 21:07:28 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:07:28 [INFO] =============== Response received len=2423
# 21:07:28 [INFO] [llm]   PXD061009_PubText.json -> 56/82 fields filled in row 0 (+30 via LLM)
# 21:07:28 [INFO] Written 2 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061009_PubText.sdrf.csv
# 21:07:28 [INFO] -- [8/15] PXD061090_PubText.json --
# 21:07:28 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD061090_PubText.sdrf.csv
# 21:07:28 [INFO] Deduplicated: 6 row(s) → 1 unique N/A pattern(s)
# 21:07:28 [INFO] Filling 63 field(s) for group of 6 row(s)…
# 21:07:28 [INFO] Chars: Paper18053 = M16510+A1440+T103
# 21:07:28 [INFO] Tokens: Paper4512 = M4127+A360+T25
# 21:07:28 [INFO] Context limit 22912 Available 10292 = CT22912-MT8192-FT4428
# 21:07:40 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:07:40 [INFO] Pass2 inventory approx tokens 1451/12524 available
# [llm_fillgaps debug] pass2_inventory_tokens~1451 available~12524 raw_chars=5804 trimmed_chars=5804
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=7240 inventory_compact_chars=5804 pass2_chars=2189
# 21:07:42 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:07:42 [INFO] =============== Response received len=567
# 21:07:42 [INFO] [llm]   PXD061090_PubText.json -> 37/82 fields filled in row 0 (+18 via LLM)
# 21:07:42 [INFO] Written 6 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061090_PubText.sdrf.csv
# 21:07:42 [INFO] -- [9/15] PXD061136_PubText.json --
# 21:07:42 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD061136_PubText.sdrf.csv
# 21:07:42 [INFO] Deduplicated: 2 row(s) → 1 unique N/A pattern(s)
# 21:07:42 [INFO] Filling 62 field(s) for group of 2 row(s)…
# 21:07:42 [INFO] Chars: Paper14321 = M12776+A1443+T102
# 21:07:42 [INFO] Tokens: Paper3579 = M3194+A360+T25
# 21:07:42 [INFO] Context limit 22912 Available 10380 = CT22912-MT8192-FT4340
# 21:10:04 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:10:04 [INFO] Pass2 inventory approx tokens 12526/12526 available
# [llm_fillgaps debug] pass2_inventory_tokens~12526 available~12526 raw_chars=64424 trimmed_chars=50104
# 21:10:04 [INFO] Pass2 inventory trimmed 64424->50104 chars to stay within context budget.
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=71815 inventory_compact_chars=50104 pass2_chars=2180
# 21:10:08 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:10:08 [INFO] =============== Response received len=982
# 21:10:08 [INFO] [llm]   PXD061136_PubText.json -> 42/82 fields filled in row 0 (+22 via LLM)
# 21:10:08 [INFO] Written 2 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061136_PubText.sdrf.csv
# 21:10:08 [INFO] -- [10/15] PXD061195_PubText.json --
# 21:10:08 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD061195_PubText.sdrf.csv
# 21:10:08 [INFO] Deduplicated: 1376 row(s) → 1 unique N/A pattern(s)
# 21:10:08 [INFO] Filling 52 field(s) for group of 1376 row(s)…
# 21:10:08 [INFO] Chars: Paper8115 = M6426+A1565+T124
# 21:10:08 [INFO] Tokens: Paper2028 = M1606+A391+T31
# 21:10:08 [INFO] Context limit 22912 Available 10841 = CT22912-MT8192-FT3879
# 21:12:43 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:12:43 [INFO] Pass2 inventory approx tokens 11202/12496 available
# [llm_fillgaps debug] pass2_inventory_tokens~11202 available~12496 raw_chars=44808 trimmed_chars=44808
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=80071 inventory_compact_chars=44808 pass2_chars=2300
# 21:12:48 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:12:48 [INFO] =============== Response received len=1536
# 21:12:48 [INFO] [llm]   PXD061195_PubText.json -> 44/82 fields filled in row 0 (+14 via LLM)
# 21:12:48 [INFO] Written 1376 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061195_PubText.sdrf.csv
# 21:12:48 [INFO] -- [11/15] PXD061285_PubText.json --
# 21:12:48 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD061285_PubText.sdrf.csv
# 21:12:48 [INFO] Deduplicated: 60 row(s) → 1 unique N/A pattern(s)
# 21:12:48 [INFO] Filling 58 field(s) for group of 60 row(s)…
# 21:12:48 [INFO] Chars: Paper32585 = M31071+A1383+T131
# 21:12:48 [INFO] Tokens: Paper8144 = M7767+A345+T32
# 21:12:48 [INFO] Context limit 22912 Available 10535 = CT22912-MT8192-FT4185
# 21:13:02 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:13:02 [INFO] Pass2 inventory approx tokens 905/12515 available
# [llm_fillgaps debug] pass2_inventory_tokens~905 available~12515 raw_chars=3620 trimmed_chars=3620
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=6447 inventory_compact_chars=3620 pass2_chars=2227
# 21:13:04 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:13:04 [INFO] =============== Response received len=547
# 21:13:04 [INFO] [llm]   PXD061285_PubText.json -> 38/82 fields filled in row 0 (+14 via LLM)
# 21:13:04 [INFO] Written 60 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061285_PubText.sdrf.csv
# 21:13:04 [INFO] -- [12/15] PXD062014_PubText.json --
# 21:13:04 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD062014_PubText.sdrf.csv
# 21:13:04 [INFO] Deduplicated: 24 row(s) → 1 unique N/A pattern(s)
# 21:13:04 [INFO] Filling 60 field(s) for group of 24 row(s)…
# 21:13:04 [INFO] Chars: Paper28051 = M26655+A1300+T96
# 21:13:04 [INFO] Tokens: Paper7012 = M6663+A325+T24
# 21:13:04 [INFO] Context limit 22912 Available 10437 = CT22912-MT8192-FT4283
# 21:14:51 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:14:51 [INFO] Pass2 inventory approx tokens 6936/12515 available
# [llm_fillgaps debug] pass2_inventory_tokens~6936 available~12515 raw_chars=27746 trimmed_chars=27746
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=53709 inventory_compact_chars=27746 pass2_chars=2224
# 21:14:54 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:14:54 [INFO] =============== Response received len=1247
# 21:14:54 [INFO] [llm]   PXD062014_PubText.json -> 41/82 fields filled in row 0 (+19 via LLM)
# 21:14:54 [INFO] Written 24 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062014_PubText.sdrf.csv
# 21:14:54 [INFO] -- [13/15] PXD062469_PubText.json --
# 21:14:54 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD062469_PubText.sdrf.csv
# 21:14:54 [INFO] Deduplicated: 32 row(s) → 1 unique N/A pattern(s)
# 21:14:54 [INFO] Filling 57 field(s) for group of 32 row(s)…
# 21:14:54 [INFO] Chars: Paper15040 = M13574+A1377+T89
# 21:14:54 [INFO] Tokens: Paper3759 = M3393+A344+T22
# 21:14:54 [INFO] Context limit 22912 Available 10603 = CT22912-MT8192-FT4117
# 21:17:18 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:17:18 [INFO] Pass2 inventory approx tokens 11392/12503 available
# [llm_fillgaps debug] pass2_inventory_tokens~11392 available~12503 raw_chars=45568 trimmed_chars=45568
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=67346 inventory_compact_chars=45568 pass2_chars=2272
# 21:17:21 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:17:21 [INFO] =============== Response received len=745
# 21:17:21 [INFO] [llm]   PXD062469_PubText.json -> 46/82 fields filled in row 0 (+21 via LLM)
# 21:17:21 [INFO] Written 32 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062469_PubText.sdrf.csv
# 21:17:21 [INFO] -- [14/15] PXD062877_PubText.json --
# 21:17:21 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD062877_PubText.sdrf.csv
# 21:17:21 [INFO] Deduplicated: 48 row(s) → 1 unique N/A pattern(s)
# 21:17:21 [INFO] Filling 54 field(s) for group of 48 row(s)…
# 21:17:21 [INFO] Chars: Paper33748 = M32232+A1422+T94
# 21:17:21 [INFO] Tokens: Paper8436 = M8058+A355+T23
# 21:17:21 [INFO] Context limit 22912 Available 10769 = CT22912-MT8192-FT3951
# 21:19:12 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:19:12 [INFO] Pass2 inventory approx tokens 10157/12495 available
# [llm_fillgaps debug] pass2_inventory_tokens~10157 available~12495 raw_chars=40631 trimmed_chars=40631
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=40631 inventory_compact_chars=40631 pass2_chars=2305
# 21:20:45 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:20:45 [INFO] =============== Response received len=37331
# 21:20:45 [WARNING] JSON parse failed, trying repair…
# 21:20:45 [ERROR] Patch parse failed (Expecting ':' delimiter: line 1030 column 6 (char 37332)) — skipping this group.
# 21:20:45 [INFO] [llm]   PXD062877_PubText.json -> 28/82 fields filled in row 0 (+0 via LLM)
# 21:20:45 [INFO] Written 48 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062877_PubText.sdrf.csv
# 21:20:45 [INFO] -- [15/15] PXD064564_PubText.json --
# 21:20:45 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/rules_0000/PXD064564_PubText.sdrf.csv
# 21:20:45 [INFO] Deduplicated: 30 row(s) → 1 unique N/A pattern(s)
# 21:20:45 [INFO] Filling 60 field(s) for group of 30 row(s)…
# 21:20:45 [INFO] Chars: Paper17871 = M16236+A1497+T138
# 21:20:45 [INFO] Tokens: Paper4467 = M4059+A374+T34
# 21:20:45 [INFO] Context limit 22912 Available 10475 = CT22912-MT8192-FT4245
# 21:23:01 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:23:01 [INFO] Pass2 inventory approx tokens 12512/12512 available
# [llm_fillgaps debug] pass2_inventory_tokens~12512 available~12512 raw_chars=69116 trimmed_chars=50048
# 21:23:01 [INFO] Pass2 inventory trimmed 69116->50048 chars to stay within context budget.
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=70032 inventory_compact_chars=50048 pass2_chars=2236
# 21:23:04 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:23:04 [INFO] =============== Response received len=700
# 21:23:04 [INFO] [llm]   PXD064564_PubText.json -> 28/82 fields filled in row 0 (+6 via LLM)
# 21:23:04 [INFO] Written 30 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD064564_PubText.sdrf.csv
#
# 15/15 file(s) processed.
#   LLM CSVs   -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/

# %% [markdown]
# ## Next iteration(s) of LLM stage (gap filling)

# %%
# Preparing to run next iteration of second (LLM) stage (gap filling)
RUN=1
print((RUN, OUTPUT_DIR))

DIR_RUN2 = str(OUTPUT_DIR).replace(f"R{RUN}",f"R{(RUN+1)}")
Path(DIR_RUN2).mkdir(parents=True, exist_ok=True)
RUN+1, DIR_RUN2
# Out:
# (1, PosixPath('/kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1'))
# (2, '/kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2')

# %%
# Running next iteration of second (LLM) stage (gap filling)

# !python main_fill.py --stage llm --fill-from {OUTPUT_DIR} --max-tokens {MAX_TOKENS} --context-limit {CONTEXT_LIMIT} --llm-dir "{DIR_RUN2}"  --model {LLM_MODEL} --base-url {api_base} --api-key {api_key} --pattern PXD*.json "{TEST_TEXT_DIR}"
# Out:
# 21:23:04 [INFO] Pattern 'PXD*.json' in /kaggle/input/competitions/harmonizing-the-data-of-your-data/Test PubText/Test PubText -> 15 file(s)
# 21:23:04 [INFO] -- [1/15] PXD004010_PubText.json --
# 21:23:04 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD004010_PubText.sdrf.csv
# 21:23:06 [INFO] Deduplicated: 10 row(s) → 1 unique N/A pattern(s)
# 21:23:06 [INFO] Filling 53 field(s) for group of 10 row(s)…
# 21:23:06 [INFO] Chars: Paper9630 = M8027+A1493+T110
# 21:23:06 [INFO] Tokens: Paper2406 = M2006+A373+T27
# 21:23:06 [INFO] Context limit 22912 Available 10818 = CT22912-MT8192-FT3902
# 21:25:43 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:25:43 [INFO] Pass2 inventory approx tokens 8769/12496 available
# [llm_fillgaps debug] pass2_inventory_tokens~8769 available~12496 raw_chars=35079 trimmed_chars=35079
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=85157 inventory_compact_chars=35079 pass2_chars=2302
# 21:25:49 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:25:49 [INFO] =============== Response received len=2765
# 21:25:49 [INFO] [llm]   PXD004010_PubText.json -> 29/82 fields filled in row 0 (+0 via LLM)
# 21:25:49 [INFO] Written 10 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD004010_PubText.sdrf.csv
# 21:25:49 [INFO] -- [2/15] PXD016436_PubText.json --
# 21:25:49 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD016436_PubText.sdrf.csv
# 21:25:49 [INFO] Deduplicated: 18 row(s) → 1 unique N/A pattern(s)
# 21:25:49 [INFO] Filling 53 field(s) for group of 18 row(s)…
# 21:25:49 [INFO] Chars: Paper6853 = M6201+A577+T75
# 21:25:49 [INFO] Tokens: Paper1712 = M1550+A144+T18
# 21:25:49 [INFO] Context limit 22912 Available 10831 = CT22912-MT8192-FT3889
# 21:28:28 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:28:28 [INFO] Pass2 inventory approx tokens 12496/12496 available
# [llm_fillgaps debug] pass2_inventory_tokens~12496 available~12496 raw_chars=52193 trimmed_chars=49984
# 21:28:28 [INFO] Pass2 inventory trimmed 52193->49984 chars to stay within context budget.
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=85958 inventory_compact_chars=49984 pass2_chars=2303
# 21:28:30 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:28:30 [INFO] =============== Response received len=171
# 21:28:30 [INFO] [llm]   PXD016436_PubText.json -> 34/82 fields filled in row 0 (+5 via LLM)
# 21:28:30 [INFO] Written 18 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD016436_PubText.sdrf.csv
# 21:28:30 [INFO] -- [3/15] PXD019519_PubText.json --
# 21:28:30 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD019519_PubText.sdrf.csv
# 21:28:30 [INFO] Deduplicated: 6 row(s) → 1 unique N/A pattern(s)
# 21:28:30 [INFO] Filling 26 field(s) for group of 6 row(s)…
# 21:28:30 [INFO] Chars: Paper43567 = M42096+A1394+T77
# 21:28:30 [INFO] Tokens: Paper10891 = M10524+A348+T19
# 21:28:30 [INFO] Context limit 22912 Available 12040 = CT22912-MT8192-FT2680
# 21:28:37 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:28:37 [INFO] Pass2 inventory approx tokens 479/12428 available
# [llm_fillgaps debug] pass2_inventory_tokens~479 available~12428 raw_chars=1917 trimmed_chars=1917
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=2368 inventory_compact_chars=1917 pass2_chars=2574
# 21:28:41 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:28:41 [INFO] =============== Response received len=1648
# 21:28:41 [INFO] [llm]   PXD019519_PubText.json -> 58/82 fields filled in row 0 (+2 via LLM)
# 21:28:41 [INFO] Written 6 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD019519_PubText.sdrf.csv
# 21:28:41 [INFO] -- [4/15] PXD025663_PubText.json --
# 21:28:41 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD025663_PubText.sdrf.csv
# 21:28:41 [INFO] Deduplicated: 12 row(s) → 1 unique N/A pattern(s)
# 21:28:41 [INFO] Filling 49 field(s) for group of 12 row(s)…
# 21:28:41 [INFO] Chars: Paper18589 = M16465+A2069+T55
# 21:28:41 [INFO] Tokens: Paper4646 = M4116+A517+T13
# 21:28:41 [INFO] Context limit 22912 Available 10977 = CT22912-MT8192-FT3743
# 21:30:58 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:30:58 [INFO] Pass2 inventory approx tokens 6982/12469 available
# [llm_fillgaps debug] pass2_inventory_tokens~6982 available~12469 raw_chars=27930 trimmed_chars=27930
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=69124 inventory_compact_chars=27930 pass2_chars=2410
# 21:33:19 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:33:19 [INFO] =============== Response received len=61483
# 21:33:19 [WARNING] JSON parse failed, trying repair…
# 21:33:19 [ERROR] Patch parse failed (Expecting ':' delimiter: line 1698 column 15 (char 61484)) — skipping this group.
# 21:33:19 [INFO] [llm]   PXD025663_PubText.json -> 33/82 fields filled in row 0 (+0 via LLM)
# 21:33:19 [INFO] Written 12 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD025663_PubText.sdrf.csv
# 21:33:19 [INFO] -- [5/15] PXD040582_PubText.json --
# 21:33:19 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD040582_PubText.sdrf.csv
# 21:33:19 [INFO] Deduplicated: 24 row(s) → 1 unique N/A pattern(s)
# 21:33:19 [INFO] Filling 46 field(s) for group of 24 row(s)…
# 21:33:19 [INFO] Chars: Paper18376 = M17042+A1207+T127
# 21:33:19 [INFO] Tokens: Paper4592 = M4260+A301+T31
# 21:33:19 [INFO] Context limit 22912 Available 11156 = CT22912-MT8192-FT3564
# 21:35:41 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:35:41 [INFO] Pass2 inventory approx tokens 11406/12476 available
# [llm_fillgaps debug] pass2_inventory_tokens~11406 available~12476 raw_chars=45627 trimmed_chars=45627
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=69119 inventory_compact_chars=45627 pass2_chars=2382
# 21:35:43 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:35:43 [INFO] =============== Response received len=456
# 21:35:43 [INFO] [llm]   PXD040582_PubText.json -> 50/82 fields filled in row 0 (+14 via LLM)
# 21:35:43 [INFO] Written 24 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD040582_PubText.sdrf.csv
# 21:35:43 [INFO] -- [6/15] PXD050621_PubText.json --
# 21:35:43 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD050621_PubText.sdrf.csv
# 21:35:43 [INFO] Deduplicated: 9 row(s) → 1 unique N/A pattern(s)
# 21:35:43 [INFO] Filling 64 field(s) for group of 9 row(s)…
# 21:35:43 [INFO] Chars: Paper12512 = M10943+A1424+T145
# 21:35:43 [INFO] Tokens: Paper3127 = M2735+A356+T36
# 21:35:43 [INFO] Context limit 22912 Available 10245 = CT22912-MT8192-FT4475
# 21:35:56 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:35:56 [INFO] Pass2 inventory approx tokens 964/12529 available
# [llm_fillgaps debug] pass2_inventory_tokens~964 available~12529 raw_chars=3858 trimmed_chars=3858
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=8707 inventory_compact_chars=3858 pass2_chars=2169
# 21:35:57 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:35:57 [INFO] =============== Response received len=442
# 21:35:57 [INFO] [llm]   PXD050621_PubText.json -> 18/82 fields filled in row 0 (+0 via LLM)
# 21:35:57 [INFO] Written 9 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD050621_PubText.sdrf.csv
# 21:35:57 [INFO] -- [7/15] PXD061009_PubText.json --
# 21:35:57 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061009_PubText.sdrf.csv
# 21:35:57 [INFO] Deduplicated: 2 row(s) → 1 unique N/A pattern(s)
# 21:35:57 [INFO] Filling 27 field(s) for group of 2 row(s)…
# 21:35:57 [INFO] Chars: Paper32997 = M31369+A1523+T105
# 21:35:57 [INFO] Tokens: Paper8248 = M7842+A380+T26
# 21:35:57 [INFO] Context limit 22912 Available 11946 = CT22912-MT8192-FT2774
# 21:37:58 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:37:58 [INFO] Pass2 inventory approx tokens 9489/12310 available
# [llm_fillgaps debug] pass2_inventory_tokens~9489 available~12310 raw_chars=37958 trimmed_chars=37958
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=37958 inventory_compact_chars=37958 pass2_chars=3044
# 21:38:01 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:38:01 [INFO] =============== Response received len=585
# 21:38:01 [INFO] [llm]   PXD061009_PubText.json -> 58/82 fields filled in row 0 (+3 via LLM)
# 21:38:01 [INFO] Written 2 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD061009_PubText.sdrf.csv
# 21:38:01 [INFO] -- [8/15] PXD061090_PubText.json --
# 21:38:01 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061090_PubText.sdrf.csv
# 21:38:01 [INFO] Deduplicated: 6 row(s) → 1 unique N/A pattern(s)
# 21:38:01 [INFO] Filling 46 field(s) for group of 6 row(s)…
# 21:38:01 [INFO] Chars: Paper18053 = M16510+A1440+T103
# 21:38:01 [INFO] Tokens: Paper4512 = M4127+A360+T25
# 21:38:01 [INFO] Context limit 22912 Available 11110 = CT22912-MT8192-FT3610
# 21:40:22 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:40:22 [INFO] Pass2 inventory approx tokens 10671/12493 available
# [llm_fillgaps debug] pass2_inventory_tokens~10671 available~12493 raw_chars=42686 trimmed_chars=42686
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=82973 inventory_compact_chars=42686 pass2_chars=2312
# 21:40:26 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:40:26 [INFO] =============== Response received len=1168
# 21:40:26 [INFO] [llm]   PXD061090_PubText.json -> 41/82 fields filled in row 0 (+5 via LLM)
# 21:40:26 [INFO] Written 6 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD061090_PubText.sdrf.csv
# 21:40:26 [INFO] -- [9/15] PXD061136_PubText.json --
# 21:40:26 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061136_PubText.sdrf.csv
# 21:40:26 [INFO] Deduplicated: 2 row(s) → 1 unique N/A pattern(s)
# 21:40:26 [INFO] Filling 41 field(s) for group of 2 row(s)…
# 21:40:26 [INFO] Chars: Paper14321 = M12776+A1443+T102
# 21:40:26 [INFO] Tokens: Paper3579 = M3194+A360+T25
# 21:40:26 [INFO] Context limit 22912 Available 11340 = CT22912-MT8192-FT3380
# 21:40:33 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:40:33 [INFO] Pass2 inventory approx tokens 491/12470 available
# [llm_fillgaps debug] pass2_inventory_tokens~491 available~12470 raw_chars=1965 trimmed_chars=1965
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=3924 inventory_compact_chars=1965 pass2_chars=2405
# 21:40:34 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:40:34 [INFO] =============== Response received len=322
# 21:40:34 [INFO] [llm]   PXD061136_PubText.json -> 50/82 fields filled in row 0 (+9 via LLM)
# 21:40:34 [INFO] Written 2 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD061136_PubText.sdrf.csv
# 21:40:34 [INFO] -- [10/15] PXD061195_PubText.json --
# 21:40:34 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061195_PubText.sdrf.csv
# 21:40:34 [INFO] Deduplicated: 1376 row(s) → 1 unique N/A pattern(s)
# 21:40:34 [INFO] Filling 38 field(s) for group of 1376 row(s)…
# 21:40:34 [INFO] Chars: Paper8115 = M6426+A1565+T124
# 21:40:34 [INFO] Tokens: Paper2028 = M1606+A391+T31
# 21:40:34 [INFO] Context limit 22912 Available 11464 = CT22912-MT8192-FT3256
# 21:43:13 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:43:13 [INFO] Pass2 inventory approx tokens 12463/12463 available
# [llm_fillgaps debug] pass2_inventory_tokens~12463 available~12463 raw_chars=89466 trimmed_chars=49852
# 21:43:13 [INFO] Pass2 inventory trimmed 89466->49852 chars to stay within context budget.
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=97403 inventory_compact_chars=49852 pass2_chars=2435
# 21:45:06 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:45:06 [INFO] =============== Response received len=45720
# 21:45:06 [WARNING] JSON parse failed, trying repair…
# 21:45:06 [INFO] [llm]   PXD061195_PubText.json -> 53/82 fields filled in row 0 (+9 via LLM)
# 21:45:06 [INFO] Written 1376 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD061195_PubText.sdrf.csv
# 21:45:06 [INFO] -- [11/15] PXD061285_PubText.json --
# 21:45:06 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061285_PubText.sdrf.csv
# 21:45:06 [INFO] Deduplicated: 60 row(s) → 1 unique N/A pattern(s)
# 21:45:06 [INFO] Filling 45 field(s) for group of 60 row(s)…
# 21:45:06 [INFO] Chars: Paper32585 = M31071+A1383+T131
# 21:45:06 [INFO] Tokens: Paper8144 = M7767+A345+T32
# 21:45:06 [INFO] Context limit 22912 Available 11119 = CT22912-MT8192-FT3601
# 21:46:56 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:46:56 [INFO] Pass2 inventory approx tokens 8595/12465 available
# [llm_fillgaps debug] pass2_inventory_tokens~8595 available~12465 raw_chars=34382 trimmed_chars=34382
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=59458 inventory_compact_chars=34382 pass2_chars=2426
# 21:47:01 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:47:01 [INFO] =============== Response received len=1703
# 21:47:01 [INFO] [llm]   PXD061285_PubText.json -> 50/82 fields filled in row 0 (+13 via LLM)
# 21:47:01 [INFO] Written 60 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD061285_PubText.sdrf.csv
# 21:47:01 [INFO] -- [12/15] PXD062014_PubText.json --
# 21:47:01 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062014_PubText.sdrf.csv
# 21:47:01 [INFO] Deduplicated: 24 row(s) → 1 unique N/A pattern(s)
# 21:47:01 [INFO] Filling 42 field(s) for group of 24 row(s)…
# 21:47:01 [INFO] Chars: Paper28051 = M26655+A1300+T96
# 21:47:01 [INFO] Tokens: Paper7012 = M6663+A325+T24
# 21:47:01 [INFO] Context limit 22912 Available 11298 = CT22912-MT8192-FT3422
# 21:47:10 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:47:10 [INFO] Pass2 inventory approx tokens 616/12459 available
# [llm_fillgaps debug] pass2_inventory_tokens~616 available~12459 raw_chars=2467 trimmed_chars=2467
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=4885 inventory_compact_chars=2467 pass2_chars=2450
# 21:47:11 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:47:11 [INFO] =============== Response received len=281
# 21:47:11 [INFO] [llm]   PXD062014_PubText.json -> 41/82 fields filled in row 0 (+1 via LLM)
# 21:47:11 [INFO] Written 24 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD062014_PubText.sdrf.csv
# 21:47:11 [INFO] -- [13/15] PXD062469_PubText.json --
# 21:47:11 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062469_PubText.sdrf.csv
# 21:47:11 [INFO] Deduplicated: 32 row(s) → 1 unique N/A pattern(s)
# 21:47:11 [INFO] Filling 37 field(s) for group of 32 row(s)…
# 21:47:11 [INFO] Chars: Paper15040 = M13574+A1377+T89
# 21:47:11 [INFO] Tokens: Paper3759 = M3393+A344+T22
# 21:47:11 [INFO] Context limit 22912 Available 11511 = CT22912-MT8192-FT3209
# 21:49:40 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:49:40 [INFO] Pass2 inventory approx tokens 10596/12443 available
# [llm_fillgaps debug] pass2_inventory_tokens~10596 available~12443 raw_chars=42386 trimmed_chars=42386
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=90709 inventory_compact_chars=42386 pass2_chars=2515
# 21:49:44 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:49:44 [INFO] =============== Response received len=1337
# 21:49:44 [INFO] [llm]   PXD062469_PubText.json -> 59/82 fields filled in row 0 (+14 via LLM)
# 21:49:44 [INFO] Written 32 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD062469_PubText.sdrf.csv
# 21:49:44 [INFO] -- [14/15] PXD062877_PubText.json --
# 21:49:44 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062877_PubText.sdrf.csv
# 21:49:44 [INFO] Deduplicated: 48 row(s) → 1 unique N/A pattern(s)
# 21:49:44 [INFO] Filling 54 field(s) for group of 48 row(s)…
# 21:49:44 [INFO] Chars: Paper33748 = M32232+A1422+T94
# 21:49:44 [INFO] Tokens: Paper8436 = M8058+A355+T23
# 21:49:44 [INFO] Context limit 22912 Available 10769 = CT22912-MT8192-FT3951
# 21:51:35 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:51:35 [INFO] Pass2 inventory approx tokens 10157/12495 available
# [llm_fillgaps debug] pass2_inventory_tokens~10157 available~12495 raw_chars=40631 trimmed_chars=40631
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=40631 inventory_compact_chars=40631 pass2_chars=2305
# 21:53:09 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:53:09 [INFO] =============== Response received len=37331
# 21:53:09 [WARNING] JSON parse failed, trying repair…
# 21:53:09 [ERROR] Patch parse failed (Expecting ':' delimiter: line 1030 column 6 (char 37332)) — skipping this group.
# 21:53:09 [INFO] [llm]   PXD062877_PubText.json -> 28/82 fields filled in row 0 (+0 via LLM)
# 21:53:09 [INFO] Written 48 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD062877_PubText.sdrf.csv
# 21:53:09 [INFO] -- [15/15] PXD064564_PubText.json --
# 21:53:09 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD064564_PubText.sdrf.csv
# 21:53:09 [INFO] Deduplicated: 30 row(s) → 1 unique N/A pattern(s)
# 21:53:09 [INFO] Filling 54 field(s) for group of 30 row(s)…
# 21:53:09 [INFO] Chars: Paper17871 = M16236+A1497+T138
# 21:53:09 [INFO] Tokens: Paper4467 = M4059+A374+T34
# 21:53:09 [INFO] Context limit 22912 Available 10737 = CT22912-MT8192-FT3983
# 21:55:27 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:55:27 [INFO] Pass2 inventory approx tokens 9201/12481 available
# [llm_fillgaps debug] pass2_inventory_tokens~9201 available~12481 raw_chars=36805 trimmed_chars=36805
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=79287 inventory_compact_chars=36805 pass2_chars=2363
# 21:55:31 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:55:31 [INFO] =============== Response received len=1113
# 21:55:31 [INFO] [llm]   PXD064564_PubText.json -> 34/82 fields filled in row 0 (+6 via LLM)
# 21:55:31 [INFO] Written 30 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD064564_PubText.sdrf.csv
#
# 15/15 file(s) processed.
#   LLM CSVs   -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/

# %%
# Preparing to run next iteration of second (LLM) stage (gap filling)

DIR_RUN3 = str(OUTPUT_DIR).replace(f"R{RUN}",f"R{(RUN+2)}")
Path(DIR_RUN3).mkdir(parents=True, exist_ok=True)
RUN+2, DIR_RUN3
# Out:
# (3, '/kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3')

# %%
# Running next iteration of second (LLM) stage (gap filling) 

# !python main_fill.py --stage llm --fill-from {DIR_RUN2} --max-tokens {MAX_TOKENS} --context-limit {CONTEXT_LIMIT} --llm-dir "{DIR_RUN3}"  --model {LLM_MODEL} --base-url {api_base} --api-key {api_key} --pattern PXD*.json "{TEST_TEXT_DIR}"
# Out:
# 21:55:32 [INFO] Pattern 'PXD*.json' in /kaggle/input/competitions/harmonizing-the-data-of-your-data/Test PubText/Test PubText -> 15 file(s)
# 21:55:32 [INFO] -- [1/15] PXD004010_PubText.json --
# 21:55:32 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD004010_PubText.sdrf.csv
# 21:55:34 [INFO] Deduplicated: 10 row(s) → 1 unique N/A pattern(s)
# 21:55:34 [INFO] Filling 53 field(s) for group of 10 row(s)…
# 21:55:34 [INFO] Chars: Paper9630 = M8027+A1493+T110
# 21:55:34 [INFO] Tokens: Paper2406 = M2006+A373+T27
# 21:55:34 [INFO] Context limit 22912 Available 10818 = CT22912-MT8192-FT3902
# 21:58:11 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:58:11 [INFO] Pass2 inventory approx tokens 8769/12496 available
# [llm_fillgaps debug] pass2_inventory_tokens~8769 available~12496 raw_chars=35079 trimmed_chars=35079
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=85157 inventory_compact_chars=35079 pass2_chars=2302
# 21:58:18 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:58:18 [INFO] =============== Response received len=2765
# 21:58:18 [INFO] [llm]   PXD004010_PubText.json -> 29/82 fields filled in row 0 (+0 via LLM)
# 21:58:18 [INFO] Written 10 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD004010_PubText.sdrf.csv
# 21:58:18 [INFO] -- [2/15] PXD016436_PubText.json --
# 21:58:18 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD016436_PubText.sdrf.csv
# 21:58:18 [INFO] Deduplicated: 18 row(s) → 1 unique N/A pattern(s)
# 21:58:18 [INFO] Filling 48 field(s) for group of 18 row(s)…
# 21:58:18 [INFO] Chars: Paper6853 = M6201+A577+T75
# 21:58:18 [INFO] Tokens: Paper1712 = M1550+A144+T18
# 21:58:18 [INFO] Context limit 22912 Available 11094 = CT22912-MT8192-FT3626
# 21:58:27 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:58:27 [INFO] Pass2 inventory approx tokens 1336/12476 available
# [llm_fillgaps debug] pass2_inventory_tokens~1336 available~12476 raw_chars=5345 trimmed_chars=5345
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=6090 inventory_compact_chars=5345 pass2_chars=2381
# 21:58:28 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:58:28 [INFO] =============== Response received len=279
# 21:58:28 [INFO] [llm]   PXD016436_PubText.json -> 41/82 fields filled in row 0 (+7 via LLM)
# 21:58:28 [INFO] Written 18 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD016436_PubText.sdrf.csv
# 21:58:28 [INFO] -- [3/15] PXD019519_PubText.json --
# 21:58:28 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD019519_PubText.sdrf.csv
# 21:58:28 [INFO] Deduplicated: 6 row(s) → 1 unique N/A pattern(s)
# 21:58:28 [INFO] Filling 25 field(s) for group of 6 row(s)…
# 21:58:28 [INFO] Chars: Paper43567 = M42096+A1394+T77
# 21:58:28 [INFO] Tokens: Paper10891 = M10524+A348+T19
# 21:58:28 [INFO] Context limit 22912 Available 12089 = CT22912-MT8192-FT2631
# 21:58:35 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:58:35 [INFO] Pass2 inventory approx tokens 371/12425 available
# [llm_fillgaps debug] pass2_inventory_tokens~371 available~12425 raw_chars=1487 trimmed_chars=1487
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=2541 inventory_compact_chars=1487 pass2_chars=2585
# 21:58:36 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 21:58:36 [INFO] =============== Response received len=303
# 21:58:36 [INFO] [llm]   PXD019519_PubText.json -> 58/82 fields filled in row 0 (+1 via LLM)
# 21:58:36 [INFO] Written 6 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD019519_PubText.sdrf.csv
# 21:58:36 [INFO] -- [4/15] PXD025663_PubText.json --
# 21:58:36 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD025663_PubText.sdrf.csv
# 21:58:36 [INFO] Deduplicated: 12 row(s) → 1 unique N/A pattern(s)
# 21:58:36 [INFO] Filling 49 field(s) for group of 12 row(s)…
# 21:58:36 [INFO] Chars: Paper18589 = M16465+A2069+T55
# 21:58:36 [INFO] Tokens: Paper4646 = M4116+A517+T13
# 21:58:36 [INFO] Context limit 22912 Available 10977 = CT22912-MT8192-FT3743
# 22:00:52 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:00:52 [INFO] Pass2 inventory approx tokens 6982/12469 available
# [llm_fillgaps debug] pass2_inventory_tokens~6982 available~12469 raw_chars=27930 trimmed_chars=27930
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=69124 inventory_compact_chars=27930 pass2_chars=2410
# 22:03:13 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:03:13 [INFO] =============== Response received len=61483
# 22:03:13 [WARNING] JSON parse failed, trying repair…
# 22:03:13 [ERROR] Patch parse failed (Expecting ':' delimiter: line 1698 column 15 (char 61484)) — skipping this group.
# 22:03:13 [INFO] [llm]   PXD025663_PubText.json -> 33/82 fields filled in row 0 (+0 via LLM)
# 22:03:13 [INFO] Written 12 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD025663_PubText.sdrf.csv
# 22:03:13 [INFO] -- [5/15] PXD040582_PubText.json --
# 22:03:13 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD040582_PubText.sdrf.csv
# 22:03:13 [INFO] Deduplicated: 24 row(s) → 1 unique N/A pattern(s)
# 22:03:13 [INFO] Filling 33 field(s) for group of 24 row(s)…
# 22:03:13 [INFO] Chars: Paper18376 = M17042+A1207+T127
# 22:03:13 [INFO] Tokens: Paper4592 = M4260+A301+T31
# 22:03:13 [INFO] Context limit 22912 Available 11737 = CT22912-MT8192-FT2983
# 22:03:19 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:03:19 [INFO] Pass2 inventory approx tokens 497/12452 available
# [llm_fillgaps debug] pass2_inventory_tokens~497 available~12452 raw_chars=1991 trimmed_chars=1991
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=3352 inventory_compact_chars=1991 pass2_chars=2476
# 22:03:21 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:03:21 [INFO] =============== Response received len=1229
# 22:03:21 [INFO] [llm]   PXD040582_PubText.json -> 49/82 fields filled in row 0 (+0 via LLM)
# 22:03:21 [INFO] Written 24 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD040582_PubText.sdrf.csv
# 22:03:21 [INFO] -- [6/15] PXD050621_PubText.json --
# 22:03:21 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD050621_PubText.sdrf.csv
# 22:03:21 [INFO] Deduplicated: 9 row(s) → 1 unique N/A pattern(s)
# 22:03:21 [INFO] Filling 64 field(s) for group of 9 row(s)…
# 22:03:21 [INFO] Chars: Paper12512 = M10943+A1424+T145
# 22:03:21 [INFO] Tokens: Paper3127 = M2735+A356+T36
# 22:03:21 [INFO] Context limit 22912 Available 10245 = CT22912-MT8192-FT4475
# 22:03:34 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:03:34 [INFO] Pass2 inventory approx tokens 964/12529 available
# [llm_fillgaps debug] pass2_inventory_tokens~964 available~12529 raw_chars=3858 trimmed_chars=3858
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=8707 inventory_compact_chars=3858 pass2_chars=2169
# 22:03:35 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:03:35 [INFO] =============== Response received len=442
# 22:03:35 [INFO] [llm]   PXD050621_PubText.json -> 18/82 fields filled in row 0 (+0 via LLM)
# 22:03:35 [INFO] Written 9 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD050621_PubText.sdrf.csv
# 22:03:35 [INFO] -- [7/15] PXD061009_PubText.json --
# 22:03:35 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD061009_PubText.sdrf.csv
# 22:03:35 [INFO] Deduplicated: 2 row(s) → 1 unique N/A pattern(s)
# 22:03:35 [INFO] Filling 25 field(s) for group of 2 row(s)…
# 22:03:35 [INFO] Chars: Paper32997 = M31369+A1523+T105
# 22:03:35 [INFO] Tokens: Paper8248 = M7842+A380+T26
# 22:03:35 [INFO] Context limit 22912 Available 12013 = CT22912-MT8192-FT2707
# 22:05:35 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:35 [INFO] Pass2 inventory approx tokens 12286/12286 available
# [llm_fillgaps debug] pass2_inventory_tokens~12286 available~12286 raw_chars=57167 trimmed_chars=49144
# 22:05:35 [INFO] Pass2 inventory trimmed 57167->49144 chars to stay within context budget.
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=63243 inventory_compact_chars=49144 pass2_chars=3142
# 22:05:39 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:39 [INFO] =============== Response received len=924
# 22:05:39 [INFO] [llm]   PXD061009_PubText.json -> 60/82 fields filled in row 0 (+3 via LLM)
# 22:05:39 [INFO] Written 2 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD061009_PubText.sdrf.csv
# 22:05:39 [INFO] -- [8/15] PXD061090_PubText.json --
# 22:05:39 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD061090_PubText.sdrf.csv
# 22:05:39 [INFO] Deduplicated: 6 row(s) → 1 unique N/A pattern(s)
# 22:05:39 [INFO] Filling 41 field(s) for group of 6 row(s)…
# 22:05:39 [INFO] Chars: Paper18053 = M16510+A1440+T103
# 22:05:39 [INFO] Tokens: Paper4512 = M4127+A360+T25
# 22:05:39 [INFO] Context limit 22912 Available 11331 = CT22912-MT8192-FT3389
# 22:05:46 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:46 [INFO] Pass2 inventory approx tokens 601/12468 available
# [llm_fillgaps debug] pass2_inventory_tokens~601 available~12468 raw_chars=2406 trimmed_chars=2406
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=4124 inventory_compact_chars=2406 pass2_chars=2412
# 22:05:47 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:47 [INFO] =============== Response received len=212
# 22:05:47 [INFO] [llm]   PXD061090_PubText.json -> 42/82 fields filled in row 0 (+1 via LLM)
# 22:05:47 [INFO] Written 6 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD061090_PubText.sdrf.csv
# 22:05:47 [INFO] -- [9/15] PXD061136_PubText.json --
# 22:05:47 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD061136_PubText.sdrf.csv
# 22:05:47 [INFO] Deduplicated: 2 row(s) → 1 unique N/A pattern(s)
# 22:05:47 [INFO] Filling 33 field(s) for group of 2 row(s)…
# 22:05:47 [INFO] Chars: Paper14321 = M12776+A1443+T102
# 22:05:47 [INFO] Tokens: Paper3579 = M3194+A360+T25
# 22:05:47 [INFO] Context limit 22912 Available 11699 = CT22912-MT8192-FT3021
# 22:08:18 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:08:18 [INFO] Pass2 inventory approx tokens 11795/12448 available
# [llm_fillgaps debug] pass2_inventory_tokens~11795 available~12448 raw_chars=47183 trimmed_chars=47183
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=86873 inventory_compact_chars=47183 pass2_chars=2493
# 22:10:10 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:10 [INFO] =============== Response received len=39075
# 22:10:10 [WARNING] JSON parse failed, trying repair…
# 22:10:10 [ERROR] Patch parse failed (Expecting ':' delimiter: line 1204 column 17 (char 39076)) — skipping this group.
# 22:10:10 [INFO] [llm]   PXD061136_PubText.json -> 49/82 fields filled in row 0 (+0 via LLM)
# 22:10:10 [INFO] Written 2 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD061136_PubText.sdrf.csv
# 22:10:10 [INFO] -- [10/15] PXD061195_PubText.json --
# 22:10:10 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD061195_PubText.sdrf.csv
# 22:10:10 [INFO] Deduplicated: 1376 row(s) → 1 unique N/A pattern(s)
# 22:10:10 [INFO] Filling 30 field(s) for group of 1376 row(s)…
# 22:10:10 [INFO] Chars: Paper8115 = M6426+A1565+T124
# 22:10:10 [INFO] Tokens: Paper2028 = M1606+A391+T31
# 22:10:10 [INFO] Context limit 22912 Available 11754 = CT22912-MT8192-FT2966
# 22:12:51 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:12:51 [INFO] Pass2 inventory approx tokens 11665/12443 available
# [llm_fillgaps debug] pass2_inventory_tokens~11665 available~12443 raw_chars=46662 trimmed_chars=46662
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=90288 inventory_compact_chars=46662 pass2_chars=2512
# 22:12:54 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:12:54 [INFO] =============== Response received len=281
# 22:12:54 [INFO] [llm]   PXD061195_PubText.json -> 57/82 fields filled in row 0 (+5 via LLM)
# 22:12:54 [INFO] Written 1376 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD061195_PubText.sdrf.csv
# 22:12:54 [INFO] -- [11/15] PXD061285_PubText.json --
# 22:12:54 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD061285_PubText.sdrf.csv
# 22:12:54 [INFO] Deduplicated: 60 row(s) → 1 unique N/A pattern(s)
# 22:12:54 [INFO] Filling 33 field(s) for group of 60 row(s)…
# 22:12:54 [INFO] Chars: Paper32585 = M31071+A1383+T131
# 22:12:54 [INFO] Tokens: Paper8144 = M7767+A345+T32
# 22:12:54 [INFO] Context limit 22912 Available 11651 = CT22912-MT8192-FT3069
# 22:14:48 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:14:48 [INFO] Pass2 inventory approx tokens 12429/12429 available
# [llm_fillgaps debug] pass2_inventory_tokens~12429 available~12429 raw_chars=56934 trimmed_chars=49716
# 22:14:48 [INFO] Pass2 inventory trimmed 56934->49716 chars to stay within context budget.
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=56934 inventory_compact_chars=49716 pass2_chars=2571
# 22:14:51 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:14:51 [INFO] =============== Response received len=330
# 22:14:51 [INFO] [llm]   PXD061285_PubText.json -> 50/82 fields filled in row 0 (+1 via LLM)
# 22:14:51 [INFO] Written 60 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD061285_PubText.sdrf.csv
# 22:14:51 [INFO] -- [12/15] PXD062014_PubText.json --
# 22:14:51 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD062014_PubText.sdrf.csv
# 22:14:51 [INFO] Deduplicated: 24 row(s) → 1 unique N/A pattern(s)
# 22:14:51 [INFO] Filling 42 field(s) for group of 24 row(s)…
# 22:14:51 [INFO] Chars: Paper28051 = M26655+A1300+T96
# 22:14:51 [INFO] Tokens: Paper7012 = M6663+A325+T24
# 22:14:51 [INFO] Context limit 22912 Available 11298 = CT22912-MT8192-FT3422
# 22:15:00 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:15:00 [INFO] Pass2 inventory approx tokens 616/12459 available
# [llm_fillgaps debug] pass2_inventory_tokens~616 available~12459 raw_chars=2467 trimmed_chars=2467
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=4885 inventory_compact_chars=2467 pass2_chars=2450
# 22:15:01 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:15:01 [INFO] =============== Response received len=281
# 22:15:01 [INFO] [llm]   PXD062014_PubText.json -> 41/82 fields filled in row 0 (+1 via LLM)
# 22:15:01 [INFO] Written 24 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD062014_PubText.sdrf.csv
# 22:15:01 [INFO] -- [13/15] PXD062469_PubText.json --
# 22:15:01 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD062469_PubText.sdrf.csv
# 22:15:01 [INFO] Deduplicated: 32 row(s) → 1 unique N/A pattern(s)
# 22:15:01 [INFO] Filling 23 field(s) for group of 32 row(s)…
# 22:15:01 [INFO] Chars: Paper15040 = M13574+A1377+T89
# 22:15:01 [INFO] Tokens: Paper3759 = M3393+A344+T22
# 22:15:01 [INFO] Context limit 22912 Available 12162 = CT22912-MT8192-FT2558
# 22:17:34 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:17:34 [INFO] Pass2 inventory approx tokens 10866/12409 available
# [llm_fillgaps debug] pass2_inventory_tokens~10866 available~12409 raw_chars=43464 trimmed_chars=43464
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=88191 inventory_compact_chars=43464 pass2_chars=2650
# 22:17:38 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:17:38 [INFO] =============== Response received len=962
# 22:17:38 [INFO] [llm]   PXD062469_PubText.json -> 63/82 fields filled in row 0 (+4 via LLM)
# 22:17:38 [INFO] Written 32 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD062469_PubText.sdrf.csv
# 22:17:38 [INFO] -- [14/15] PXD062877_PubText.json --
# 22:17:38 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD062877_PubText.sdrf.csv
# 22:17:38 [INFO] Deduplicated: 48 row(s) → 1 unique N/A pattern(s)
# 22:17:38 [INFO] Filling 54 field(s) for group of 48 row(s)…
# 22:17:38 [INFO] Chars: Paper33748 = M32232+A1422+T94
# 22:17:38 [INFO] Tokens: Paper8436 = M8058+A355+T23
# 22:17:38 [INFO] Context limit 22912 Available 10769 = CT22912-MT8192-FT3951
# 22:19:30 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:30 [INFO] Pass2 inventory approx tokens 10157/12495 available
# [llm_fillgaps debug] pass2_inventory_tokens~10157 available~12495 raw_chars=40631 trimmed_chars=40631
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=40631 inventory_compact_chars=40631 pass2_chars=2305
# 22:21:05 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:21:05 [INFO] =============== Response received len=37331
# 22:21:05 [WARNING] JSON parse failed, trying repair…
# 22:21:05 [ERROR] Patch parse failed (Expecting ':' delimiter: line 1030 column 6 (char 37332)) — skipping this group.
# 22:21:05 [INFO] [llm]   PXD062877_PubText.json -> 28/82 fields filled in row 0 (+0 via LLM)
# 22:21:05 [INFO] Written 48 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD062877_PubText.sdrf.csv
# 22:21:05 [INFO] -- [15/15] PXD064564_PubText.json --
# 22:21:05 [INFO] [llm] Loading rules CSV from /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R2/PXD064564_PubText.sdrf.csv
# 22:21:05 [INFO] Deduplicated: 30 row(s) → 1 unique N/A pattern(s)
# 22:21:05 [INFO] Filling 48 field(s) for group of 30 row(s)…
# 22:21:05 [INFO] Chars: Paper17871 = M16236+A1497+T138
# 22:21:05 [INFO] Tokens: Paper4467 = M4059+A374+T34
# 22:21:05 [INFO] Context limit 22912 Available 11015 = CT22912-MT8192-FT3705
# 22:23:25 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:23:25 [INFO] Pass2 inventory approx tokens 8946/12471 available
# [llm_fillgaps debug] pass2_inventory_tokens~8946 available~12471 raw_chars=35785 trimmed_chars=35785
# [llm_fillgaps debug] fresh_pass2=1 context_limit=22912 max_tokens=8192 inventory_raw_chars=78717 inventory_compact_chars=35785 pass2_chars=2403
# 22:23:26 [INFO] HTTP Request: POST http://127.0.0.1:8080/v1/chat/completions "HTTP/1.1 200 OK"
# 22:23:26 [INFO] =============== Response received len=58
# 22:23:26 [INFO] [llm]   PXD064564_PubText.json -> 35/82 fields filled in row 0 (+1 via LLM)
# 22:23:26 [INFO] Written 30 rows -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/PXD064564_PubText.sdrf.csv
#
# 15/15 file(s) processed.
#   LLM CSVs   -> /kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R3/

# %% [markdown]
# ### Any improvements over the iterative runs ?

# %%
import pandas as pd
from src.eval import score, dataframe_diff, print_column_value_diffs

pxds = pd.read_csv(SAMPLE_SUB)["PXD"].unique()
for pxd in pxds:
    run1 = pd.read_csv(Path(DIR_RUN2) / f"{pxd}_PubText.sdrf.csv")
    run1["PXD"] = pxd
    run2 = pd.read_csv(Path(DIR_RUN3) / f"{pxd}_PubText.sdrf.csv")
    run2["PXD"] = pxd

    f1, harm_norm, harm_subm, eval_df = score(run1, run2, row_id_column_name="ID")
    print(f"## {pxd} F1={f1}")
    display(eval_df.loc[eval_df["f1"]<0.8].head())
    
    diff = dataframe_diff(run1, run2)
    if diff.shape[0] > 0:
        #diff.to_csv(str(SUBMISSION).replace(".csv", "_normalized_diff.csv"), index=False)
        print(f"## {pxd} Column differences")
        print_column_value_diffs(diff)
# Out:
# ## PXD004010 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []
# ## PXD050621 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []
# ## PXD062014 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []
# ## PXD061136 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []
# ## PXD016436 F1=0.9228395061728395
#           pxd                    AnnotationType  precision  recall        f1  \
# 3   PXD016436             Comment[GradientTime]        0.0     0.0  0.000000
# 12  PXD016436  Comment[NumberOfMissedCleavages]        0.0     0.0  0.000000
# 16  PXD016436         Characteristics[CellLine]        0.0     0.0  0.000000
# 39  PXD016436         Characteristics[Compound]        0.0     0.0  0.000000
# 47  PXD016436     Characteristics[Modification]        0.4     0.5  0.444444
#
#     jacc
# 3    0.0
# 12   0.0
# 16   0.0
# 39   0.0
# 47   0.8
# ## PXD016436 Column differences
#
# Column: Characteristics[CellLine]
# not applicable → bovine raw tank milk
#
# Column: Characteristics[Compound]
# not applicable → heat treatment
#
# Column: Characteristics[Modification].3
# not applicable → de-amidation
#
# Column: Comment[EnrichmentMethod]
# not applicable → FASP
#
# Column: Comment[GradientTime]
# not applicable → 50 min
#
# Column: Comment[NumberOfMissedCleavages]
# not applicable → 2
# ## PXD062877 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []
# ## PXD064564 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []
# ## PXD062469 F1=0.9583333333333334
#           pxd                        AnnotationType  precision  recall   f1  \
# 34  PXD062469   Characteristics[DevelopmentalStage]        0.0     0.0  0.0
# 51  PXD062469  Characteristics[GeneticModification]        0.0     0.0  0.0
# 71  PXD062469      FactorValue[GeneticModification]        0.0     0.0  0.0
#
#     jacc
# 34   0.0
# 51   0.0
# 71   0.0
# ## PXD062469 Column differences
#
# Column: Characteristics[DevelopmentalStage]
# not applicable → adult
#
# Column: Characteristics[GeneticModification]
# not applicable → BRCA1 knockout
#
# Column: FactorValue[GeneticModification]
# not applicable → BRCA1 knockout
# ## PXD061009 F1=0.9722222222222222
#           pxd                       AnnotationType  precision  recall   f1  \
# 34  PXD061009  Characteristics[DevelopmentalStage]        0.0     0.0  0.0
# 67  PXD061009                 FactorValue[Disease]        0.0     0.0  0.0
#
#     jacc
# 34   0.0
# 67   0.0
# ## PXD061009 Column differences
#
# Column: Characteristics[DevelopmentalStage]
# not applicable → adult
#
# Column: FactorValue[Disease]
# not applicable → glioblastoma
# ## PXD061195 F1=0.9444444444444444
#           pxd                    AnnotationType  precision  recall   f1  jacc
# 11  PXD061195          Comment[MS2MassAnalyzer]        0.0     0.0  0.0   0.0
# 12  PXD061195  Comment[NumberOfMissedCleavages]        0.0     0.0  0.0   0.0
# 36  PXD061195    Comment[FragmentMassTolerance]        0.0     0.0  0.0   0.0
# 65  PXD061195          Comment[CollisionEnergy]        0.0     0.0  0.0   0.0
# ## PXD061195 Column differences
#
# Column: Comment[CollisionEnergy]
# not applicable → 32
#
# Column: Comment[FragmentMassTolerance]
# not applicable → 0.02
#
# Column: Comment[MS2MassAnalyzer]
# not applicable → Orbitrap
#
# Column: Comment[NumberOfMissedCleavages]
# not applicable → 2
# ## PXD061090 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []
# ## PXD040582 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []
# ## PXD025663 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []
# ## PXD019519 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []
# ## PXD061285 F1=1.0
# Empty DataFrame
# Columns: [pxd, AnnotationType, precision, recall, f1, jacc]
# Index: []

# %% [markdown]
# ## Combine into submission

# %%
RUN=1
SDRF_FILES_OUTPUT = OUTPUT_DIR

RUN=2
SDRF_FILES_OUTPUT=DIR_RUN2

RUN=3
SDRF_FILES_OUTPUT=DIR_RUN3

# %%
# --- CONFIG ---
output_folder = Path(SDRF_FILES_OUTPUT)  # folder with all SDRF CSVs
sample_csv = Path(SAMPLE_SUB)  # reference sample CSV
SUBMISSION_MODEL = str(SUBMISSION).replace(".csv", f"_{LLM_MODEL}_T{TEMPERATURE}_R{RUN}.csv")

# --- load reference columns ---
sample_df = pd.read_csv(sample_csv)
cols_order = sample_df.columns.tolist()  # only columns to keep, including PXD and ID

# --- iterate SDRF CSVs ---
all_dfs = []
text_dir = Path(TEST_TEXT_DIR)
files = sorted(text_dir.glob("PXD*.json"))
# we want them same order as in the text dor
for i, jf in enumerate(files, 1):
    pxd = jf.name.split("_")[0]
    # Extract PXD from filename
    f = output_folder / f"{pxd}_PubText.sdrf.csv"
    df = pd.read_csv(f)
    # Extract PXD from filename
    try:
        #pxd = f.stem.split("_")[0]
        df["PXD"] = pxd  # fill the PXD column
        all_dfs.append(df)
    except Exception as err:
        log.error(err)
    
# --- concatenate all files ---
combined_df = pd.concat(all_dfs, ignore_index=True)

# --- ensure all sample columns exist ---
for c in cols_order:
    if c not in combined_df.columns:
        combined_df[c] = pd.NA

# --- assign consecutive IDs ---
if "ID" in cols_order:
    combined_df["ID"] = range(1, len(combined_df) + 1)

# --- keep only columns from sample CSV and in order ---
combined_df = combined_df[cols_order]
# no idea, but this is in SampleSubmission
combined_df['Usage'] = ['Public' if i % 2 == 0 else 'Private' for i in range(len(combined_df))]
combined_df = combined_df.replace('not applicable', 'Not Applicable')

# not all factors are same as characteristics
# it's more complicated to be handled later 
# do not override fv , LLM should handle them in main
#fv_headers = ["Bait","CellPart","Compound","Disease","FractionIdentifier","GeneticModification","Temperature","Treatment"]
#for fv in fv_headers:
#    c = 'Comment' if fv == "FractionIdentifier" else 'Characteristics'
#    combined_df[f'FactorValue[{fv}]'] = combined_df[f'{c}[{fv}]'] 

# defaults, mandatory for proteomics
mandatory_col = "Characteristics[CleavageAgent]"
combined_df.loc[combined_df[mandatory_col] == "Not Applicable", mandatory_col] = "AC=MS:1001251; NT=Trypsin"
mandatory_col = "Comment[AcquisitionMethod]"
combined_df.loc[combined_df[mandatory_col] == "Not Applicable", mandatory_col] = "DDA"

# ---  save final combined CSV ---
combined_df.to_csv(SUBMISSION_MODEL, index=False)
print(f"Combined SDRF dataframe saved -> {SUBMISSION_MODEL} dataset shape {combined_df.shape}")
# Out:
# Combined SDRF dataframe saved -> /kaggle/working/submission_qwen3-vl-4b-instruct_T0_R3.csv dataset shape (1659, 81)

# %% [markdown]
# ## Normalise with keyword maps and Ontology Lookup Service
# using sdrf_pipeline.ols and modelmess cv_map

# %%
from src.cv_map import build_cv_normaliser, normalise_submission
cv_normalizer = build_cv_normaliser(use_ols=True) 
assert "NT=Orbitrap;AC=MS:1000484", cv_normalizer.normalise('Comment[MS2MassAnalyzer]', 'Orbitrap')

assert "Homo sapiens" ==  cv_normalizer.normalise('Characteristics[Organism]', 'human')
assert "Homo sapiens" ==  cv_normalizer.normalise('Characteristics[Organism]', "Homo sapiens")
print(cv_normalizer.normalise('Characteristics[Sex]', "fEmale"))
print(cv_normalizer.normalise('Characteristics[CellLine]', "HeLa"))
print(cv_normalizer.normalise('Characteristics[CellType]', "HeLa"))
# Out:
# 2026-03-30 22:23:33,018 INFO No cached ontology files found. Downloading from GitHub...
# 2026-03-30 22:23:33,018 INFO Downloading ontology file: bto.parquet
# Downloading file 'bto.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/bto.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:23:38,271 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/bto.parquet
# 2026-03-30 22:23:38,272 INFO Downloading ontology file: chebi.parquet
# Downloading file 'chebi.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/chebi.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:23:43,919 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/chebi.parquet
# 2026-03-30 22:23:43,919 INFO Downloading ontology file: cl.parquet
# Downloading file 'cl.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/cl.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:23:49,421 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/cl.parquet
# 2026-03-30 22:23:49,421 INFO Downloading ontology file: clo.parquet
# Downloading file 'clo.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/clo.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:23:54,886 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/clo.parquet
# 2026-03-30 22:23:54,886 INFO Downloading ontology file: doid.parquet
# Downloading file 'doid.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/doid.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:24:00,364 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/doid.parquet
# 2026-03-30 22:24:00,365 INFO Downloading ontology file: efo.parquet
# Downloading file 'efo.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/efo.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:24:06,241 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/efo.parquet
# 2026-03-30 22:24:06,242 INFO Downloading ontology file: envo.parquet
# Downloading file 'envo.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/envo.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:24:11,554 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/envo.parquet
# 2026-03-30 22:24:11,555 INFO Downloading ontology file: gaz.parquet
# Downloading file 'gaz.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/gaz.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:24:18,374 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/gaz.parquet
# 2026-03-30 22:24:18,375 INFO Downloading ontology file: hancestro.parquet
# Downloading file 'hancestro.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/hancestro.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:24:23,540 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/hancestro.parquet
# 2026-03-30 22:24:23,540 INFO Downloading ontology file: mod.parquet
# Downloading file 'mod.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/mod.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:24:29,089 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/mod.parquet
# 2026-03-30 22:24:29,089 INFO Downloading ontology file: mondo.parquet
# Downloading file 'mondo.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/mondo.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:24:34,817 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/mondo.parquet
# 2026-03-30 22:24:34,817 INFO Downloading ontology file: ncbitaxon.parquet
# Downloading file 'ncbitaxon.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/ncbitaxon.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:24:43,907 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/ncbitaxon.parquet
# 2026-03-30 22:24:43,907 INFO Downloading ontology file: ncit.parquet
# Downloading file 'ncit.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/ncit.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:24:49,901 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/ncit.parquet
# 2026-03-30 22:24:49,902 INFO Downloading ontology file: pato.parquet
# Downloading file 'pato.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/pato.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:24:55,257 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/pato.parquet
# 2026-03-30 22:24:55,258 INFO Downloading ontology file: pride.parquet
# Downloading file 'pride.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/pride.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:25:00,508 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/pride.parquet
# 2026-03-30 22:25:00,508 INFO Downloading ontology file: psi-ms.parquet
# Downloading file 'psi-ms.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/psi-ms.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:25:05,769 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/psi-ms.parquet
# 2026-03-30 22:25:05,769 INFO Downloading ontology file: uberon.parquet
# Downloading file 'uberon.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/uberon.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:25:11,238 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/uberon.parquet
# 2026-03-30 22:25:11,238 INFO Downloading ontology file: unimod.parquet
# Downloading file 'unimod.parquet' from 'https://raw.githubusercontent.com/bigbio/sdrf-pipelines/v0.1.2/data/ontologies/unimod.parquet' to '/root/.cache/sdrf-pipelines/ontologies'.
# 2026-03-30 22:25:16,493 INFO Successfully cached: /root/.cache/sdrf-pipelines/ontologies/unimod.parquet
# 2026-03-30 22:25:16,494 INFO Successfully downloaded 18 ontology files
# 2026-03-30 22:25:16,494 INFO Found 18 ontology cache files: bto, chebi, cl, clo, doid, efo, envo, gaz, hancestro, mod, mondo, ncbitaxon, ncit, pato, pride, psi-ms, uberon, unimod
# 2026-03-30 22:25:16,494 INFO Using Dict cache backend
# 2026-03-30 22:25:16,494 INFO OLS cache loaded
# female
# hela
# HeLa

# %% [markdown]
# #### Make sure this warning disappears - otherwise we are not using the Ontology Lookup Service
#
# WARNING OLS dependencies not available — using keyword maps only

# %% [markdown]
# ### Normalise

# %%
from src.eval import dataframe_diff, score, print_column_value_diffs
submission_df = pd.read_csv(SUBMISSION_MODEL)
SUBMISSION_NORM = str(SUBMISSION_MODEL).replace(".csv", "_normalized.csv")
submission_norm = normalise_submission(submission_df, cv_normalizer)
submission_norm.to_csv(SUBMISSION_NORM, index=False)
submission_norm.head()
# Out:
# 2026-03-30 22:25:16,600 INFO DictBackend: loaded bto (6566 terms)
# 2026-03-30 22:25:16,622 INFO DictBackend: loaded unimod (1561 terms)
#    ID        PXD Raw Data File Characteristics[Age]  \
# 0   1  PXD004010   ad_pl03.raw       Not Applicable
# 1   2  PXD004010   ad_pl04.raw       Not Applicable
# 2   3  PXD004010   ad_pl10.raw       Not Applicable
# 3   4  PXD004010   ad_pl07.raw       Not Applicable
# 4   5  PXD004010   ad_pl08.raw       Not Applicable
#
#   Characteristics[AlkylationReagent] Characteristics[AnatomicSiteTumor]  \
# 0                                IAA                     Not Applicable
# 1                                IAA                     Not Applicable
# 2                                IAA                     Not Applicable
# 3                                IAA                     Not Applicable
# 4                                IAA                     Not Applicable
#
#   Characteristics[AncestryCategory] Characteristics[BMI]  \
# 0                    Not Applicable       Not Applicable
# 1                    Not Applicable       Not Applicable
# 2                    Not Applicable       Not Applicable
# 3                    Not Applicable       Not Applicable
# 4                    Not Applicable       Not Applicable
#
#   Characteristics[Bait]  Characteristics[BiologicalReplicate]  ...  \
# 0        Not Applicable                                     3  ...
# 1        Not Applicable                                     4  ...
# 2        Not Applicable                                    10  ...
# 3        Not Applicable                                     7  ...
# 4        Not Applicable                                     8  ...
#
#   FactorValue[Bait] FactorValue[CellPart] FactorValue[Compound]  \
# 0    Not Applicable        Not Applicable        Not Applicable
# 1    Not Applicable        Not Applicable        Not Applicable
# 2    Not Applicable        Not Applicable        Not Applicable
# 3    Not Applicable        Not Applicable        Not Applicable
# 4    Not Applicable        Not Applicable        Not Applicable
#
#   FactorValue[ConcentrationOfCompound].1 FactorValue[Disease]  \
# 0                         Not Applicable       Not Applicable
# 1                         Not Applicable       Not Applicable
# 2                         Not Applicable       Not Applicable
# 3                         Not Applicable       Not Applicable
# 4                         Not Applicable       Not Applicable
#
#   FactorValue[FractionIdentifier] FactorValue[GeneticModification]  \
# 0                  Not Applicable                   Not Applicable
# 1                  Not Applicable                   Not Applicable
# 2                  Not Applicable                   Not Applicable
# 3                  Not Applicable                   Not Applicable
# 4                  Not Applicable                   Not Applicable
#
#   FactorValue[Temperature] FactorValue[Treatment]    Usage
# 0           Not Applicable         Not Applicable   Public
# 1           Not Applicable         Not Applicable  Private
# 2           Not Applicable         Not Applicable   Public
# 3           Not Applicable         Not Applicable  Private
# 4           Not Applicable         Not Applicable   Public
#
# [5 rows x 81 columns]

# %% [markdown]
# ### Verify what the normaliser did

# %%
from src.eval import score, dataframe_diff, print_column_value_diffs
f1, harm_norm, harm_subm, eval_df = score(submission_norm, submission_df, row_id_column_name="ID")
print(f"## F1={f1}")
display(eval_df.loc[eval_df["f1"]<0.8].head())

diff = dataframe_diff(submission_df, submission_norm)
#diff.to_csv(str(SUBMISSION).replace(".csv", "_normalized_diff.csv"), index=False)
print("## Column differences")
print_column_value_diffs(diff)
# Out:
# ## F1=0.85179418742586
#           pxd                      AnnotationType  precision  recall   f1  \
# 9   PXD019519             Comment[IonizationType]        0.0     0.0  0.0
# 10  PXD019519                 Comment[Separation]        0.0     0.0  0.0
# 16  PXD019519  Characteristics[AlkylationReagent]        0.0     0.0  0.0
# 24  PXD019519           Characteristics[CellLine]        0.0     0.0  0.0
# 32  PXD019519          Comment[AcquisitionMethod]        0.0     0.0  0.0
#
#     jacc
# 9    0.0
# 10   0.0
# 16   0.0
# 24   0.0
# 32   0.0
# ## Column differences
#
# Column: Characteristics[AlkylationReagent]
# Iodoacetamide → IAA
# Chloroacetamide → CAA
#
# Column: Characteristics[CellLine]
# ANBL6 → anbl6
# HeLa → hela
# HEK 293 T → hek 293 t
# U2OS → u2os
# E. coli AB1157 → e. coli ab1157
# 3028 | 2907 | ENSA | hNP1 → 3028 | 2907 | ensa | hnp1
# rat fibroblast-like synovial cells (FLS) → rat fibroblast-like synovial cells (fls)
# HUVECs → huvecs
# HEK293T → hek293t
# DU145 (ACC 261); PC3 (ACC 465) → du145; pc3
#
# Column: Characteristics[CleavageAgent]
# Trypsin → AC=MS:1001251;NT=Trypsin
# Trypsin/LysC → AC=MS:1001251;NT=Trypsin|AC=MS:1001309;NT=Lys-C
# AC=MS:1001251; NT=Trypsin → AC=MS:1001251; AC=MS:1001251;NT=Trypsin
#
# Column: Characteristics[Label]
# label free sample → AC=MS:1002038;NT=label free sample
# TMT16-126 → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-127N → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-127C → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-128N → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-128C → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-129N → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-129C → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-130N → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-130C → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-131N → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-131C → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-132N → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-132C → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-133N → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-133C → AC=PRIDE:0000543;NT=TMT16plex
# TMT16-134N → AC=PRIDE:0000543;NT=TMT16plex
#
# Column: Characteristics[Modification]
# TMT6plex → NT=tmt6plex;AC=unimod:737
# Carbamidomethyl → NT=carbamidomethyl;AC=unimod:4
# Phospho → NT=phospho;AC=unimod:21
# Oxidation → NT=oxidation;AC=unimod:35
#
# Column: Characteristics[Modification].1
# Oxidation → NT=oxidation;AC=unimod:35
# Carbamidomethyl → NT=carbamidomethyl;AC=unimod:4
# Phospho → NT=phospho;AC=unimod:21
#
# Column: Characteristics[Modification].2
# Phospho → NT=phospho;AC=unimod:21
# Acetyl → NT=acetyl;AC=unimod:1
# Oxidation → NT=oxidation;AC=unimod:35
#
# Column: Characteristics[Modification].3
# Phospho → NT=phospho;AC=unimod:21
# Acetyl → NT=acetyl;AC=unimod:1
#
# Column: Characteristics[Modification].4
# TMT6plex → NT=tmt6plex;AC=unimod:737
#
# Column: Characteristics[Modification].5
# TMT6plex → NT=tmt6plex;AC=unimod:737
#
# Column: Characteristics[Modification].6
# TMT6plex → NT=tmt6plex;AC=unimod:737
#
# Column: Characteristics[ReductionReagent]
# Dithiothreitol → DTT
#
# Column: Comment[AcquisitionMethod]
# data-dependent acquisition → DDA
# data-independent acquisition → DIA
#
# Column: Comment[FractionationMethod]
# gel-based → NT=SDS-PAGE;AC=PRIDE:0000568
# SCX → NT=Strong cation-exchange chromatography (SCX);AC=PRIDE:0000561
#
# Column: Comment[FragmentationMethod]
# HCD → NT=HCD;AC=MS:1000422
# CID → NT=CID;AC=MS:1000133
#
# Column: Comment[Instrument]
# LTQ Orbitrap XL → AC=MS:1000449;NT=LTQ Orbitrap XL
# Q Exactive HF → AC=MS:1002523;NT=Q Exactive HF
# Orbitrap Fusion → AC=MS:1002416;NT=Orbitrap Fusion
# Q-Exactive HF X → AC=MS:1002877;NT=Q Exactive HF-X
# AB SCIEX Zeno TOF 7600 → NT=AB SCIEX Zeno TOF 7600
# Q Exactive → AC=MS:1001911;NT=Q Exactive
# TripleTOF 5600 → AC=MS:1002532;NT=TripleTOF 5600
# Orbitrap Astral → AC=MS:1003378;NT=Orbitrap Astral
#
# Column: Comment[IonizationType]
# ESI → NT=electrospray ionization;AC=MS:1000073
#
# Column: Comment[MS2MassAnalyzer]
# Orbitrap → NT=orbitrap;AC=MS:1000484
# TOF → NT=time-of-flight;AC=MS:1000084
#
# Column: Comment[Separation]
# reverse phase → NT=Reversed-phase chromatography;AC=PRIDE:0000563

# %%
SUBMISSION_MODEL
# Out:
# '/kaggle/working/submission_qwen3-vl-4b-instruct_T0_R3.csv'

# %%
ls -al /kaggle/working/
# Out:
# total 190
# drwxr-xr-x 4 root root       6 Mar 30 22:25 ./
# drwxr-xr-x 5 root root       5 Mar 30 18:10 ../
# drwxr-xr-x 5 root root       8 Mar 30 18:08 modelmess/
# drwxr-xr-x 6 root root       6 Mar 30 19:31 output_sdrfs/
# -rw-r--r-- 1 root root 1495127 Mar 30 22:23 submission_qwen3-vl-4b-instruct_T0_R3.csv
# -rw-r--r-- 1 root root 1976349 Mar 30 22:25 submission_qwen3-vl-4b-instruct_T0_R3_normalized.csv

# %%
from src.eval import score, dataframe_diff, print_column_value_diffs

# compare with gpt 5.4 if exists

if Path("/kaggle/working/submission_gpt-5.4_T0_R3_normalized.csv").exists():
    
    df1 = pd.read_csv("/kaggle/working/submission_gpt-5.4_T0_R2_normalized.csv")
    df2 = pd.read_csv("/kaggle/working/submission_gpt-5.4_T0_R3_normalized.csv")
    f1, harm_norm, harm_subm, eval_df = score(df1, df2, row_id_column_name="ID")
    print(f"## F1={f1}")
    display(eval_df.loc[eval_df["f1"]<0.8].head())
    
    diff = dataframe_diff(df1, df2)
    if diff.shape[0]==0:
       print("No differences!") 
    else:
        diff.head()
        #diff.to_csv(str(SUBMISSION).replace(".csv", "_normalized_diff.csv"), index=False)
        print("## Column differences")
        print_column_value_diffs(diff)

# %% [markdown]
# # Compare with previous submissions

# %%
# !ls /kaggle/working
# Out:
# modelmess     submission_qwen3-vl-4b-instruct_T0_R3.csv
# output_sdrfs  submission_qwen3-vl-4b-instruct_T0_R3_normalized.csv

# %%
def reorder(df, df_reference):
    # Create a tuple key temporarily
    df_keys = list(zip(df['PXD'], df['Raw Data File']))
    ref_keys = list(zip(df_reference['PXD'], df_reference['Raw Data File']))

    # map reference order to df indices
    key_to_index = {}
    for i, k in enumerate(df_keys):
        # allow duplicates: store as list of indices
        key_to_index.setdefault(k, []).append(i)

    # build new order
    new_order = []
    used = {}  # keep track of used duplicates
    for k in ref_keys:
        if k in key_to_index:
            idx_list = key_to_index[k]
            used_count = used.get(k, 0)
            if used_count < len(idx_list):
                new_order.append(idx_list[used_count])
                used[k] = used_count + 1

    # reorder df
    return df.iloc[new_order].reset_index(drop=True)

# %%
from src.eval import calculate_fill_stability , suggest_next_fills
next = suggest_next_fills(submission_norm)
display(next)
# Out:
#            PXD                              Column            Priority  \
# 565  PXD061195              FactorValue[Treatment]  Medium (Discovery)
# 553  PXD061195    FactorValue[GeneticModification]  Medium (Discovery)
# 56   PXD061195                Characteristics[BMI]  Medium (Discovery)
# 41   PXD061195   Characteristics[AncestryCategory]  Medium (Discovery)
# 433  PXD061195           Comment[EnrichmentMethod]  Medium (Discovery)
# ..         ...                                 ...                 ...
# 464  PXD061009               Comment[GradientTime]  Medium (Discovery)
# 489  PXD061136                 Comment[Separation]  Medium (Discovery)
# 69   PXD061136               Characteristics[Bait]  Medium (Discovery)
# 15   PXD061136  Characteristics[AlkylationReagent]  Medium (Discovery)
# 13   PXD061009  Characteristics[AlkylationReagent]  Medium (Discovery)
#
#     Suggested_Val  Gain_Potential
# 565    LLM_NEEDED            1376
# 553    LLM_NEEDED            1376
# 56     LLM_NEEDED            1376
# 41     LLM_NEEDED            1376
# 433    LLM_NEEDED            1376
# ..            ...             ...
# 464    LLM_NEEDED               2
# 489    LLM_NEEDED               2
# 69     LLM_NEEDED               2
# 15     LLM_NEEDED               2
# 13     LLM_NEEDED               2
#
# [569 rows x 5 columns]

# %%
from src.postprocessing import competition_aware_merge, merge_with_similarity
from src.eval import calculate_fill_stability , suggest_next_fills

BEST_SO_FAR = Path("/kaggle/input/datasets/n10705013/best-hdd2026-submissions-rule-first-then-llm")
for f in BEST_SO_FAR.glob("*.csv"):
    df = pd.read_csv(f)[sample_df.columns]
    submission_norm_same_order = reorder(submission_norm, df)
    print(f"=== {f.name} ===")
    f1, harm_norm, harm_subm, eval_df = score(df, submission_norm_same_order, row_id_column_name="ID")
    print(f"=== {f1} {f.name}")
    display(eval_df.loc[eval_df["f1"]<0.8].head())
    diff = dataframe_diff(df, submission_norm_same_order)
    #print_column_value_diffs(diff)    
    #submission_norm_same_order.to_csv("/kaggle/working/debug.csv", index=False)

    #let's merge , fill in the gaps with the best one and see if it improves
    df_merged = competition_aware_merge(df_peak=submission_norm_same_order, df_new=df)
    result = calculate_fill_stability(submission_norm_same_order, df)
    f1_merged, harm_norm, harm_subm, eval_df_merged = score(df, df_merged, row_id_column_name="ID")
    print(f"=== F1={f1} {f.name} --> F1={f1_merged} (merged)")
    print(result)
    next = suggest_next_fills(df_merged)
    display(next)
    #next.to_csv(str(SUBMISSION).replace(".csv","_next.csv"))

# %% [markdown]
# # Archive

# %%
# !zip -r {OUTPUT_DIR}.zip {OUTPUT_DIR}
# Out:
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/ (stored 0%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062469_PubText.sdrf.json (deflated 98%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD064564_PubText.sdrf.csv (deflated 96%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061285_PubText.sdrf.csv (deflated 97%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062877_PubText.sdrf.csv (deflated 97%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD016436_PubText.sdrf.json (deflated 97%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD040582_PubText.sdrf.csv (deflated 95%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061009_PubText.sdrf.csv (deflated 78%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD025663_PubText.sdrf.json (deflated 97%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062014_PubText.sdrf.json (deflated 98%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061009_PubText.sdrf.json (deflated 85%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061285_PubText.sdrf.json (deflated 98%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061090_PubText.sdrf.csv (deflated 89%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD004010_PubText.sdrf.csv (deflated 92%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD016436_PubText.sdrf.csv (deflated 94%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD064564_PubText.sdrf.json (deflated 98%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062469_PubText.sdrf.csv (deflated 96%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062014_PubText.sdrf.csv (deflated 95%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061136_PubText.sdrf.csv (deflated 79%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061090_PubText.sdrf.json (deflated 95%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD019519_PubText.sdrf.csv (deflated 86%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD025663_PubText.sdrf.csv (deflated 93%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD004010_PubText.sdrf.json (deflated 97%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061195_PubText.sdrf.csv (deflated 99%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD019519_PubText.sdrf.json (deflated 94%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD050621_PubText.sdrf.csv (deflated 93%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD040582_PubText.sdrf.json (deflated 98%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD062877_PubText.sdrf.json (deflated 98%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061136_PubText.sdrf.json (deflated 86%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD061195_PubText.sdrf.json (deflated 99%)
#   adding: kaggle/working/output_sdrfs/qwen3-vl-4b-instruct/T0/R1/PXD050621_PubText.sdrf.json (deflated 97%)

# %%
if server:
    server.stop()
# Out:
# LocalAI server stopped.

# %%
end_time = time.monotonic()
print("Execution time [HH:MM:SS.ms]:", timedelta(seconds = end_time - start_time))
print("Execution time [seconds]:", round(timedelta(seconds = end_time - start_time).total_seconds()))
# Out:
# Execution time [HH:MM:SS.ms]: 1:31:01.771160
# Execution time [seconds]: 5462
